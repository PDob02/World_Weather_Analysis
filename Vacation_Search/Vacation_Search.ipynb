# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps API key
gmaps.configure(api_key=g_key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_database.csv")
city_data_df.head()
# Out:
#    City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 0        0      Katsuura      JP  35.1333  140.3000     48.11        55
# 1        1        Xining      CN  36.6167  101.7667     16.83        60
# 2        2     Jamestown      US  42.0970  -79.2353      6.71        85
# 3        3       Kenitra      MA  34.2610   -6.5802     62.73        63
# 4        4  Punta Arenas      CL -53.1500  -70.9167     46.11        65
#
#    Cloudiness  Wind Speed Current Description
# 0          98       11.65     overcast clouds
# 1          58        2.55       broken clouds
# 2          43        1.01    scattered clouds
# 3           7        3.40           clear sky
# 4         100        9.95     overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 5         5   Port-Gentil      GA  -0.7193    8.7815     80.76        80
# 8         8       Rikitea      PF -23.1203 -134.9692     76.84        68
# 9         9     Busselton      AU -33.6500  115.3333     87.08        45
# 15       15        Avarua      CK -21.2078 -159.7750     82.45        74
# 17       17     Geraldton      AU -28.7667  114.6000     84.61        58
# 18       18    Popondetta      PG  -8.7537  148.2534     86.94        65
# 20       20        Rawson      AR -43.3002  -65.1023     77.23        23
# 28       28  General Roca      AR -39.0333  -67.5833     77.40        23
# 29       29   New Norfolk      AU -42.7826  147.0587     83.88        30
# 31       31     Hithadhoo      MV  -0.6000   73.0833     81.05        68
#
#     Cloudiness  Wind Speed Current Description
# 5           99        9.57     overcast clouds
# 8          100        6.80     overcast clouds
# 9            4       12.55           clear sky
# 15          20        8.05          few clouds
# 17           0       18.41           clear sky
# 18         100        6.02     overcast clouds
# 20          20       22.82          few clouds
# 28          54       28.66       broken clouds
# 29           0        3.00           clear sky
# 31          55        3.51       broken clouds

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# City_ID                155
# City                   155
# Country                154
# Lat                    155
# Lng                    155
# Max Temp               155
# Humidity               155
# Cloudiness             155
# Wind Speed             155
# Current Description    155
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
preferred_cities_df_not_null = preferred_cities_df.dropna()
preferred_cities_df_not_null.head(10)
# Out:
#     City_ID          City Country      Lat       Lng  Max Temp  Humidity  \
# 5         5   Port-Gentil      GA  -0.7193    8.7815     80.76        80
# 8         8       Rikitea      PF -23.1203 -134.9692     76.84        68
# 9         9     Busselton      AU -33.6500  115.3333     87.08        45
# 15       15        Avarua      CK -21.2078 -159.7750     82.45        74
# 17       17     Geraldton      AU -28.7667  114.6000     84.61        58
# 18       18    Popondetta      PG  -8.7537  148.2534     86.94        65
# 20       20        Rawson      AR -43.3002  -65.1023     77.23        23
# 28       28  General Roca      AR -39.0333  -67.5833     77.40        23
# 29       29   New Norfolk      AU -42.7826  147.0587     83.88        30
# 31       31     Hithadhoo      MV  -0.6000   73.0833     81.05        68
#
#     Cloudiness  Wind Speed Current Description
# 5           99        9.57     overcast clouds
# 8          100        6.80     overcast clouds
# 9            4       12.55           clear sky
# 15          20        8.05          few clouds
# 17           0       18.41           clear sky
# 18         100        6.02     overcast clouds
# 20          20       22.82          few clouds
# 28          54       28.66       broken clouds
# 29           0        3.00           clear sky
# 31          55        3.51       broken clouds

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df_not_null[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#             City Country  Max Temp Current Description      Lat       Lng  \
# 5    Port-Gentil      GA     80.76     overcast clouds  -0.7193    8.7815
# 8        Rikitea      PF     76.84     overcast clouds -23.1203 -134.9692
# 9      Busselton      AU     87.08           clear sky -33.6500  115.3333
# 15        Avarua      CK     82.45          few clouds -21.2078 -159.7750
# 17     Geraldton      AU     84.61           clear sky -28.7667  114.6000
# 18    Popondetta      PG     86.94     overcast clouds  -8.7537  148.2534
# 20        Rawson      AR     77.23          few clouds -43.3002  -65.1023
# 28  General Roca      AR     77.40       broken clouds -39.0333  -67.5833
# 29   New Norfolk      AU     83.88           clear sky -42.7826  147.0587
# 31     Hithadhoo      MV     81.05       broken clouds  -0.6000   73.0833
#
#    Hotel Name
# 5
# 8
# 9
# 15
# 17
# 18
# 20
# 28
# 29
# 31

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# 6b. Iterate through the hotel DataFrame.
for index, row in hotel_df.iterrows():
    # get lat, lng from df
    lat = row["Lat"]
    lng = row["Lng"]
    # 6c. Get latitude and longitude from DataFrame
    params["location"] = f"{lat},{lng}"
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    #base_url = "https://maps.googleapis.com/maps/api/directions/json?location"
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    name_address = requests.get(base_url, params=params)
    name_address = name_address.json()
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    #print(json.dumps(name_address, indent=4, sort_keys=True))
name_address
#first_hotel= hotel_df.head(1)
#print(first_hotel)
#hotel_df
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uECh2pNd29M4gWI1dHDd5tRe-9JbOtccnHAsaqEBSJZGKRtSqlrXVZC3fo9K1Kw_zXsviTtcwl64fL4d_woGVPJCrGO2r36HHeVba49hPVE5HLCiysm0PW4o-Uf5E8nEHkHvBQB5qdgpgxoEHrroNEcL8KZMGfgRxQC1LsWGSggsbGfMR5KdN_7gsyDpLl1WxkWuzSRmVPFDicX-s4mcaEt8KdJx4e-WCb2RDImkb8z7TpvMfnLUnAITEJqShLbhdkZkYc4Bs10XPfv9PU3EEk_KimtBbDNudK9xcfpwa6y3-X_YuHpV6-NwZDC1dN6LBNWXob3UMAiyG0epvLivAt2gsSFy01bGSBOYQmXICbsy5mvSIoc4eraXlapJvwOlTii2XKX-FXLiVLWTxmfqONThqvUuokfTNXNDRaMMXCWXJNXRc8kW0eus',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9297226, 'lng': 79.8331022},
#     'viewport': {'northeast': {'lat': 11.9310559802915,
#       'lng': 79.8345135802915},
#      'southwest': {'lat': 11.9283580197085, 'lng': 79.8318156197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Villa Shanti for food lovers',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2048,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106626299719381636107">Villa Shanti for food lovers</a>'],
#      'photo_reference': 'Aap_uEDohh73d7UyXcpe4cbvHdWT2bHvHgeilRhEbVAuSZH5WRGTnbcQS4fc-vWbRnsgcT8X3tyE_l8py0ter9om45dsg50FQG-bjb-C1C-qIuN6iRkyEBI_m8AYs8FNsLD7n4rheDRx2iaBgnlCTQMdoF7Xpi94I2XSxu3vAVEd0snzvtHI',
#      'width': 1366}],
#    'place_id': 'ChIJlc4YpitiUzoRdYwRO2XtHAY',
#    'plus_code': {'compound_code': 'WRHM+V6 Puducherry, India',
#     'global_code': '7J3XWRHM+V6'},
#    'price_level': 3,
#    'rating': 4.2,
#    'reference': 'ChIJlc4YpitiUzoRdYwRO2XtHAY',
#    'scope': 'GOOGLE',
#    'types': ['meal_takeaway',
#     'cafe',
#     'lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 4933,
#    'vicinity': '14, Suffren Street, White Town, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9309687, 'lng': 79.8337268},
#     'viewport': {'northeast': {'lat': 11.9323727802915,
#       'lng': 79.8350881802915},
#      'southwest': {'lat': 11.9296748197085, 'lng': 79.8323902197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Le Dupleix, Pondicherry',
#    'photos': [{'height': 4344,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113697406526622432804">Nasir M</a>'],
#      'photo_reference': 'Aap_uECx4CP6XK8QActLXaJcfH4FjzQhxkp8EXf0CUa5dUxx-gjqUd5DovPa_65iP48uRNjGx9MLim8sZCBZwf_b2k-R5IXYpsaLN2TIAFWlJBQZHf3BHoiH4JgCBbIHDmm4l8ywQrh7FRSt0n1_3Nl3oH60ca8MPvcR6tH-Tw3qfXHLhBca',
#      'width': 5792}],
#    'place_id': 'ChIJXxUnEytiUzoRrO2jfqPnR_g',
#    'plus_code': {'compound_code': 'WRJM+9F Puducherry, India',
#     'global_code': '7J3XWRJM+9F'},
#    'rating': 4.1,
#    'reference': 'ChIJXxUnEytiUzoRrO2jfqPnR_g',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 2109,
#    'vicinity': '5, Caserne Street, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.939188, 'lng': 79.8166892},
#     'viewport': {'northeast': {'lat': 11.9404406302915,
#       'lng': 79.8180024302915},
#      'southwest': {'lat': 11.9377426697085, 'lng': 79.8153044697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'HOTEL LE ROYAL PARK',
#    'photos': [{'height': 636,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116117099058065160591">HOTEL LE ROYAL PARK</a>'],
#      'photo_reference': 'Aap_uEDQjfR_Kd81ojTrTiF1vUeKBNMch3UeZYgzvLi9A_UrSe3Mx74_M65hm8UX8CjytO_euTi73zDZr4VvQFVoJSXjEfPHVvHuntuEDKJ5sOTSzF3GB_if9G0sEvWQ5XPxfQDj4BO6VUyxM8zMKBGqL3TIYpszMktPPP0hmWxXXBJPVbwJ',
#      'width': 955}],
#    'place_id': 'ChIJ7fThRHlhUzoR92zX9fnCcqA',
#    'plus_code': {'compound_code': 'WRQ8+MM Puducherry, India',
#     'global_code': '7J3XWRQ8+MM'},
#    'rating': 4.1,
#    'reference': 'ChIJ7fThRHlhUzoR92zX9fnCcqA',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5484,
#    'vicinity': '168, Kamaraj Salai, Saram, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9271361, 'lng': 79.8344984},
#     'viewport': {'northeast': {'lat': 11.9285775302915,
#       'lng': 79.83586678029151},
#      'southwest': {'lat': 11.9258795697085, 'lng': 79.83316881970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Lotus Bay View Hotel',
#    'photos': [{'height': 2252,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115849203061122301196">Niharika Agrawal</a>'],
#      'photo_reference': 'Aap_uECENc7Eppvta2b5X-zNTrcPbq5NGCqvUbnKXNkAdBRTkar4wePXmfgfv1cURM86LTSEjH6aqIA-whffdC4y9k3D06egLpbECuc_RmDO-NjHQw3Bb3fJ3G4D7u-rg2cr6lrVkSBekN1cQkUCDH-w5VDQkTyTRWVy3NXKlt3pa76HffFS',
#      'width': 4000}],
#    'place_id': 'ChIJiSsPWCliUzoRWq57KASeT0Q',
#    'plus_code': {'compound_code': 'WRGM+VQ Puducherry, India',
#     'global_code': '7J3XWRGM+VQ'},
#    'rating': 3.6,
#    'reference': 'ChIJiSsPWCliUzoRWq57KASeT0Q',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1077,
#    'vicinity': 'No. 01-B, Bazaar Saint Laurent Street, White Town, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9302768, 'lng': 79.8144042},
#     'viewport': {'northeast': {'lat': 11.93162118029151,
#       'lng': 79.81568253029151},
#      'southwest': {'lat': 11.9289232197085, 'lng': 79.8129845697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Raj Residency',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 575,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115518672825060873460">Raj Residency</a>'],
#      'photo_reference': 'Aap_uEBlk41sbJ3BJPdLUVTGtAhKI9XT3KUyDBsItdHqhdPh5CTzOSahV4CraIjvwngBpHmu_QI3_nPtPHItFK0J_UfrWHG2_J5oNV4lEf2_Qek_bTo27kQBcAuPhqea-k1skJxhci9WaX8bpqxflgk76NzNneKOo_G5Df8E2Pz_7ykJv6Ah',
#      'width': 1024}],
#    'place_id': 'ChIJU8spv51hUzoRB3HwkNg2j24',
#    'plus_code': {'compound_code': 'WRJ7+4Q Puducherry, India',
#     'global_code': '7J3XWRJ7+4Q'},
#    'rating': 4.3,
#    'reference': 'ChIJU8spv51hUzoRB3HwkNg2j24',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1244,
#    'vicinity': 'opp. to New Bus Stand, No 26 Cheran Street (Corner of Cheran Street & Pallivasal Street, opp. to New Bus Stand, Mullai Nagar Road'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9402585, 'lng': 79.8333538},
#     'viewport': {'northeast': {'lat': 11.9415937302915,
#       'lng': 79.83476578029149},
#      'southwest': {'lat': 11.9388957697085, 'lng': 79.83206781970848}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Laila's County",
#    'photos': [{'height': 1824,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110792540836047936368">Paresh Pratik</a>'],
#      'photo_reference': 'Aap_uEBEyRilEYp5zxx0eMOtITAgf_ardRMOvcv-5cM811FPQ7EYWEV-7gLH_SOabw9k9Viq9allpyXJexpDzlZ_YV010i9FBbCMsvTSpSo2X4Zq6Z2tpSujgGV0hNzsHQg0I-bwtv2HVxSevR5_U_s3VzdJlAuWwg5ljGRMWJo8X49kXdYY',
#      'width': 4000}],
#    'place_id': 'ChIJtchA-NZjUzoRYCgTQJM-Js0',
#    'plus_code': {'compound_code': 'WRRM+48 Puducherry, India',
#     'global_code': '7J3XWRRM+48'},
#    'rating': 3.7,
#    'reference': 'ChIJtchA-NZjUzoRYCgTQJM-Js0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 416,
#    'vicinity': '8 H.M.Kassim Salai Near Sardar Vallabhai Patel Salai, H.M.Kassim Salai, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.934682, 'lng': 79.83050300000001},
#     'viewport': {'northeast': {'lat': 11.9361367802915,
#       'lng': 79.83187023029151},
#      'southwest': {'lat': 11.9334388197085, 'lng': 79.8291722697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Pleasant Inn',
#    'photos': [{'height': 2322,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104145625530997694354">Subrata Kumar Banerjee</a>'],
#      'photo_reference': 'Aap_uEDo1PshX0Cr-UYzhZTxcrP2eM-G8AqKWWMyKcN8LkSBt3blTDI_LKfSi44p8Mghmxum0iR8r8Z7IbeXg6yEmG4X2g8bVYzYNdMiUYb_vuHN5a9m9XvbYBLELGDvPnMsOqfoFIPpwd9ucRL4Q0m6k1u0LDfAz69vPN1DYvqq3LNAts3b',
#      'width': 4128}],
#    'place_id': 'ChIJOfmMwJNhUzoRpkmLFEFFww0',
#    'plus_code': {'compound_code': 'WRMJ+V6 Puducherry, India',
#     'global_code': '7J3XWRMJ+V6'},
#    'rating': 3.9,
#    'reference': 'ChIJOfmMwJNhUzoRpkmLFEFFww0',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1070,
#    'vicinity': "next to Nilgiri's Super Market, 33, Ranga Pillai Street, MG Road Area, Puducherry"},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9375363, 'lng': 79.8230658},
#     'viewport': {'northeast': {'lat': 11.9387396802915,
#       'lng': 79.8243905302915},
#      'southwest': {'lat': 11.9360417197085, 'lng': 79.82169256970847}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Jayaram',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 490,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103123585991850311684">Hotel Jayaram</a>'],
#      'photo_reference': 'Aap_uEDpX2UJVL9gItsTaC7-iUCGUqh396pey95HU-kjBVT_VX0Pj2U5w4_RHkuJQqce3a4lApkthwXxWt5NJAgFJPiO4S0n9iW05JaS0PznWWyazZSB39SA_jd2JiBuwJSREA_Cs1-alOgIHil0uAytpCkThV-_4YN9smyIaY6TneGevuBw',
#      'width': 782}],
#    'place_id': 'ChIJ1TA9XXlhUzoRADSjqSU2nxg',
#    'plus_code': {'compound_code': 'WRQF+26 Puducherry, India',
#     'global_code': '7J3XWRQF+26'},
#    'rating': 4.1,
#    'reference': 'ChIJ1TA9XXlhUzoRADSjqSU2nxg',
#    'scope': 'GOOGLE',
#    'types': ['lodging',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 5320,
#    'vicinity': '90, Kamaraj Salai, Ilango Nagar, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9281038, 'lng': 79.83219849999999},
#     'viewport': {'northeast': {'lat': 11.9294467302915,
#       'lng': 79.8335852802915},
#      'southwest': {'lat': 11.9267487697085, 'lng': 79.83088731970848}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'The Richmond Hotel',
#    'photos': [{'height': 9248,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118129700506969976597">Ashish Naik</a>'],
#      'photo_reference': 'Aap_uEAe2X4QDCKUH2vHPHQTJlLIjdYogolDdX1Js_8dKsJE6Eyekv-h8fvdNs7zXo0aQfJhl4va3RC7B7nD9Ep8MgqUxW8l4ABVbwfyQGfn8J9m1_9VF1vz0CWVqCP4HmY5MtEO9LcaUgzjTj-_UqNSbeE_e2s90MfTFGGjoj2tBRDzrIIM',
#      'width': 6936}],
#    'place_id': 'ChIJvcKNMypiUzoRtkN6X14VliE',
#    'plus_code': {'compound_code': 'WRHJ+6V Puducherry, India',
#     'global_code': '7J3XWRHJ+6V'},
#    'rating': 4.2,
#    'reference': 'ChIJvcKNMypiUzoRtkN6X14VliE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 492,
#    'vicinity': '12, La Bourdonnais Street, White Town, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.94138, 'lng': 79.832101},
#     'viewport': {'northeast': {'lat': 11.9426782802915,
#       'lng': 79.8334239802915},
#      'southwest': {'lat': 11.9399803197085, 'lng': 79.8307260197085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Lotus Comfort- A Pondy Hotel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115357532835381550312">Naveen S Bhat</a>'],
#      'photo_reference': 'Aap_uEBM3cgOqhX1_10TT5VOQh3fOSdySkAYHW24wMkQs6RF8E2zRtuCAVHvTQLEDqN8a9zOPz9tjY9umsbzs6bQTwOfkdovkLiQbx3VKo-pLH_hpnYMDL-PpT0pLWhzI2mUTZjpWZRvTs0b9F9BqahKa-nqtSLXNPGGQISoR6v3S6rM31By',
#      'width': 4608}],
#    'place_id': 'ChIJo1D8qtdjUzoR1Mrl8fag42g',
#    'plus_code': {'compound_code': 'WRRJ+HR Puducherry, India',
#     'global_code': '7J3XWRRJ+HR'},
#    'rating': 3.6,
#    'reference': 'ChIJo1D8qtdjUzoR1Mrl8fag42g',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 756,
#    'vicinity': '72-A, Sardar Vallabhai Patel Salai, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.933294, 'lng': 79.835729},
#     'viewport': {'northeast': {'lat': 11.9346176802915,
#       'lng': 79.83719378029151},
#      'southwest': {'lat': 11.9319197197085, 'lng': 79.83449581970851}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'The Promenade',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 683,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108304791197604888654">The Promenade</a>'],
#      'photo_reference': 'Aap_uEDGs0K1fPMe6RDQ9-XOEClnYkNlx9B7wN1dInD_Y1EpFELRSJRoOMIGEerhNstr8XFLlF_pnBZvFJvamb5ZeNQiHlYNAEHZWO2BduqOEWHoeuoZlQSRTVTJkXDpKixq-0YvY5JsPTgHpqK95UCj0EXVK4zckWxLnfom-oFjUmzSLq1F',
#      'width': 1024}],
#    'place_id': 'ChIJd-8MryxiUzoR51gb948YN4o',
#    'plus_code': {'compound_code': 'WRMP+87 Puducherry, India',
#     'global_code': '7J3XWRMP+87'},
#    'rating': 4.2,
#    'reference': 'ChIJd-8MryxiUzoR51gb948YN4o',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 3780,
#    'vicinity': '23, Goubert Avenue, White Town, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9278702, 'lng': 79.8334795},
#     'viewport': {'northeast': {'lat': 11.9292178302915,
#       'lng': 79.8348339802915},
#      'southwest': {'lat': 11.9265198697085, 'lng': 79.83213601970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': "Hotel De L'Orient, 18th Century, Puducherry",
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 550,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109219165846654460770">Dune de l&#39;Orient</a>'],
#      'photo_reference': 'Aap_uEA0inNifaUw386tJhR67WwbuAHoLbmK04m_8r1Qqy2RTCz1gyaukQLGRSWQOnhi_w3P73kvFMFYIMzNl0962VeXe9CgLvD2VppXO78Na0y6byMq6CJuAvOBQgjT8NkIrwcQnH0o52OR9ti39iBpJ4ajC4IeRyY4uLPatAdXFUqCprZz',
#      'width': 1280}],
#    'place_id': 'ChIJZxHb7StiUzoRW5br4DZTLXE',
#    'plus_code': {'compound_code': 'WRHM+49 Puducherry, India',
#     'global_code': '7J3XWRHM+49'},
#    'rating': 4.2,
#    'reference': 'ChIJZxHb7StiUzoRW5br4DZTLXE',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 347,
#    'vicinity': '17, Romain Rolland Street, White Town, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9318307, 'lng': 79.81767860000001},
#     'viewport': {'northeast': {'lat': 11.9331142302915,
#       'lng': 79.81898893029151},
#      'southwest': {'lat': 11.9304162697085, 'lng': 79.8162909697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Green Palace',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 428,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117183406060849867206">Hotel Green Palace</a>'],
#      'photo_reference': 'Aap_uEDSN3wh9IkQSs_7FbS4YhhZ-nm9XRARAHh5TSaHLh0bT6u2ts7w1ogPKBBFHy392GiVZhAr2i_hq58gHUvKm8MQGGaXdfTFwLHLlj8n_hfQMaLS3-fQFaIkqT12lC7dcXn--4ZmqYINGJnmvuWA9AIkb_N2hsZXmj3lxEAbrWH33TYg',
#      'width': 640}],
#    'place_id': 'ChIJSUIFPIJhUzoR6u1YF_O3QR8',
#    'plus_code': {'compound_code': 'WRJ9+P3 Puducherry, India',
#     'global_code': '7J3XWRJ9+P3'},
#    'rating': 4,
#    'reference': 'ChIJSUIFPIJhUzoR6u1YF_O3QR8',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1401,
#    'vicinity': '140, Maraimalai Adigal Salai, Near New Bus Stand, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.931879, 'lng': 79.8148107},
#     'viewport': {'northeast': {'lat': 11.9332370802915,
#       'lng': 79.8161282302915},
#      'southwest': {'lat': 11.9305391197085, 'lng': 79.81343026970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Sri Sabthagiri',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101930206561807653154">HOTEL SRI SABTHAGIRI</a>'],
#      'photo_reference': 'Aap_uEBN31FOsp3u2WHRfYBiKWBRWeAl1mnnEcilUUACLL7cX9bd_qkbDni6VBxUw6MfTmHDSiFRjsLL2qFfjsa9efEkxkk0bSKoT7hzmPq47oKYCRsx7kWlErlgGaW2z4xY4J1GphA6DAOgeI0LBCIJUAgnBkZLLQLAjIuKNVwlhtvlhbVa',
#      'width': 5184}],
#    'place_id': 'ChIJLx7pOoJhUzoRxGkST6h47qo',
#    'plus_code': {'compound_code': 'WRJ7+QW Puducherry, India',
#     'global_code': '7J3XWRJ7+QW'},
#    'rating': 3.8,
#    'reference': 'ChIJLx7pOoJhUzoRxGkST6h47qo',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1620,
#    'vicinity': 'Opp. Main Bus Terminus, 223-225, Maraimalai Adigal Salai, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9524958, 'lng': 79.8295318},
#     'viewport': {'northeast': {'lat': 11.9539314302915,
#       'lng': 79.83091828029151},
#      'southwest': {'lat': 11.9512334697085, 'lng': 79.82822031970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Ginger Pondicherry',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101090283185825100205">arpita huddar</a>'],
#      'photo_reference': 'Aap_uEDqmCn2e5XRms7V3qYwGBvRCm2swILjuXTVOBr19nnpvicIubQwLVZwBvbLArO8_YcqYxjugKOfO24fzegK_aJLlJcuAqAbmXmrOoH72OgVUyc1uGIEaLbMvuBYcAZJuUWkWZ4sZ2Z8FTsceqTvAYXKgrQjgl8GG2UDuIepI1JO6S8S',
#      'width': 3024}],
#    'place_id': 'ChIJsUnxiEFeUzoRl4ovxhQgcdI',
#    'plus_code': {'compound_code': 'XR2H+XR Puducherry, India',
#     'global_code': '7J3XXR2H+XR'},
#    'rating': 3.7,
#    'reference': 'ChIJsUnxiEFeUzoRl4ovxhQgcdI',
#    'scope': 'GOOGLE',
#    'types': ['real_estate_agency',
#     'lodging',
#     'travel_agency',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 3033,
#    'vicinity': 'Old Venus Theatre, Karuvadikuppam Main Road Saram, Revenue Village, Marie Oulgaret, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9285184, 'lng': 79.83369979999999},
#     'viewport': {'northeast': {'lat': 11.9297947302915,
#       'lng': 79.83503313029149},
#      'southwest': {'lat': 11.9270967697085, 'lng': 79.83233516970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Palais de Mahe - CGH Earth',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102379135047881447063">Palais de Mahe - CGH Earth</a>'],
#      'photo_reference': 'Aap_uEBLMOSLBs4RNarbuvlVj7-lQ6JoXRtV-ugpmPaRtD1czJt-Bezr2IeU85T8etJ0t55AUqV1ijzevJOo0g3JDEJv18kK9t6tHhyyKbhOww8psLWPx8TZ9lYj1DnfogEMaHVZmpAwmpmVhjd2HeIpeSzzWuoCMBRsf7-u2t_urxm6qgiv',
#      'width': 5760}],
#    'place_id': 'ChIJn_D3wCtiUzoRA7xnDPbPp34',
#    'plus_code': {'compound_code': 'WRHM+CF Puducherry, India',
#     'global_code': '7J3XWRHM+CF'},
#    'rating': 4.4,
#    'reference': 'ChIJn_D3wCtiUzoRA7xnDPbPp34',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 903,
#    'vicinity': 'Bussy Street, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9407133, 'lng': 79.7921047},
#     'viewport': {'northeast': {'lat': 11.9419984302915,
#       'lng': 79.7934685302915},
#      'southwest': {'lat': 11.9393004697085, 'lng': 79.79077056970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Hotel Tamizh Park',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112454678169367517319">Sivà Srèé Rangà</a>'],
#      'photo_reference': 'Aap_uEC7ugOKtdnF4Zd5F9ALqhlSr_f2jftk-JzzigrPMnrjX-63x7LfMOeYqAwqrLaysn5_IIhKGysjzxujqd1mv-4kzbQkUJOAPs9NbQJHuR3qyv5PkPBm5gR4XKBgZKE3IEScettJxjamzhM7Hal8ruFOlAmxYYHX5m0UxkTxWxnaC09V',
#      'width': 2268}],
#    'place_id': 'ChIJcdPG6wRhUzoRtkA1rBY3akc',
#    'plus_code': {'compound_code': 'WQRR+7R Puducherry, India',
#     'global_code': '7J3XWQRR+7R'},
#    'rating': 3.8,
#    'reference': 'ChIJcdPG6wRhUzoRtkA1rBY3akc',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 1856,
#    'vicinity': 'indira gandhi medical college Marie Oulgaret, 330, Vazhudavoor Road, Marie Oulgaret, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9414061, 'lng': 79.80766609999999},
#     'viewport': {'northeast': {'lat': 11.9428523302915,
#       'lng': 79.80897273029149},
#      'southwest': {'lat': 11.9401543697085, 'lng': 79.80627476970848}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Accord Puducherry',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4912,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110494954557036361004">Accord Puducherry</a>'],
#      'photo_reference': 'Aap_uEC2T-o6N9lr2GkxXhqbBfQsMFE8G4C0iA0qs2_79ZpZwkcKL7ueraIBw8mBYKQYNEZHc_chyKT1lNZzjID1PJvBgDZFQo9KUxzuzE-qXto7ELqUOarSe-UXL_mFSvEUty7mb-nYi7b3uWdQ27vlPbx7n5qeqasopj9ECLapJ-eDtQR9',
#      'width': 7360}],
#    'place_id': 'ChIJI3a-3KxhUzoRVxUjVOMHTQw',
#    'plus_code': {'compound_code': 'WRR5+H3 Puducherry, India',
#     'global_code': '7J3XWRR5+H3'},
#    'rating': 4.2,
#    'reference': 'ChIJI3a-3KxhUzoRVxUjVOMHTQw',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 5014,
#    'vicinity': '1, Thilagar Nagar, Ellaipillaichavady, Aruthra Nagar, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9300619, 'lng': 79.8283553},
#     'viewport': {'northeast': {'lat': 11.9314289802915,
#       'lng': 79.8296144302915},
#      'southwest': {'lat': 11.9287310197085, 'lng': 79.8269164697085}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'Le Mirage',
#    'photos': [{'height': 1365,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102179622827259942537">Le Mirage</a>'],
#      'photo_reference': 'Aap_uEBSVFU1a6k24on855iFFAYdV9B00UlxCOnpGEXk0j_5rN27E3vLEFs2AE-0V45i49N0d_4EB9P_8VGUXU8c_zL21z72HPZX7hrxC4O47I8dEOWPoXP6yo-ZnEM-FUyOPDZbZWrQOkmltJS8MyZdFeQ41DTM8lOTtHnf_B2cIG3oJgjg',
#      'width': 2048}],
#    'place_id': 'ChIJUyAeXoBhUzoR_b_b2WWY-0E',
#    'plus_code': {'compound_code': 'WRJH+28 Puducherry, India',
#     'global_code': '7J3XWRJH+28'},
#    'rating': 3.9,
#    'reference': 'ChIJUyAeXoBhUzoR_b_b2WWY-0E',
#    'scope': 'GOOGLE',
#    'types': ['lodging', 'point_of_interest', 'establishment'],
#    'user_ratings_total': 573,
#    'vicinity': 'No. 475, M.G. Road, Candappa Mudaliar Street Corner, Beside Puma exclusive store, 475, Mahatma Gandhi Road, Puducherry'},
#   {'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 11.9172533, 'lng': 79.8098145},
#     'viewport': {'northeast': {'lat': 11.9186603802915,
#       'lng': 79.8110560302915},
#      'southwest': {'lat': 11.9159624197085, 'lng': 79.80835806970849}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#    'icon_background_color': '#909CE1',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#    'name': 'The Sunway Manor',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5484,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106425099246494728187">The Sunway Manor</a>'],
#      'photo_reference': 'Aap_uEAPuaaeP61otWGTZd-Am0Ic8THnwo3X7SdFJGTsMX5Y1aFeicI3GALh_L3-FBkpSUilDdz-gJdX4EDFROQp5sEmR9RRUVKqhLYYYBgpBy-BlEWUNjJCDRKZKOAO0aH86mpiujLwtsuQq3LdbH_kWZCUuB4-7X8edwM6wZjrNgctm53p',
#      'width': 7320}],
#    'place_id': 'ChIJG_c_-JZhUzoRtzf9_Lzyb30',
#    'plus_code': {'compound_code': 'WR85+WW Puducherry, India',
#     'global_code': '7J3XWR85+WW'},
#    'rating': 4.2,
#    'reference': 'ChIJG_c_-JZhUzoRtzf9_Lzyb30',
#    'scope': 'GOOGLE',
#    'types': ['spa',
#     'lodging',
#     'bar',
#     'restaurant',
#     'food',
#     'point_of_interest',
#     'establishment'],
#    'user_ratings_total': 4455,
#    'vicinity': '155/D, 100 Feet Road, Mudaliarpet, Puducherry'}],
#  'status': 'OK'}

# %%
# 7. Drop the rows where there is no Hotel Name.
#no nulls
hotel_df.count()
hotel_df_not_null = hotel_df.dropna()
hotel_df_not_null
# Out:
#             City Country  Max Temp Current Description      Lat       Lng  \
# 5    Port-Gentil      GA     80.76     overcast clouds  -0.7193    8.7815
# 8        Rikitea      PF     76.84     overcast clouds -23.1203 -134.9692
# 9      Busselton      AU     87.08           clear sky -33.6500  115.3333
# 15        Avarua      CK     82.45          few clouds -21.2078 -159.7750
# 17     Geraldton      AU     84.61           clear sky -28.7667  114.6000
# ..           ...     ...       ...                 ...      ...       ...
# 665      Fayaoue      NC     82.54          light rain -20.6500  166.5333
# 670    Innisfail      AU     85.21     overcast clouds -17.5333  146.0333
# 678  Karanganyar      ID     85.82     overcast clouds  -6.7072  111.0834
# 679   Queanbeyan      AU     82.98     overcast clouds -35.3500  149.2333
# 687  Pondicherry      IN     77.65     overcast clouds  11.9300   79.8300
#
#     Hotel Name
# 5
# 8
# 9
# 15
# 17
# ..         ...
# 665
# 670
# 678
# 679
# 687
#
# [154 rows x 7 columns]

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_vacation.csv"

# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """

"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 

# 11b. Display the figure

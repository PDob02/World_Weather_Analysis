# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
city_data = []
print(city_data)
# Out:
# []

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ef308af85e93f02acdc1dc26269d6a14

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_description})

# If an error is experienced, skip the city.
    except Exception as e:
        print(e)
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kawana waters
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 1 | katsuura
# Processing Record 3 of Set 1 | xining
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | kenitra
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | port-gentil
# Processing Record 8 of Set 1 | dikson
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | presidente epitacio
# Processing Record 14 of Set 1 | bethel
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | samusu
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | cidreira
# Processing Record 20 of Set 1 | geraldton
# Processing Record 21 of Set 1 | popondetta
# Processing Record 22 of Set 1 | orange
# Processing Record 23 of Set 1 | rawson
# Processing Record 24 of Set 1 | zhangjiakou
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | tuatapere
# Processing Record 27 of Set 1 | alcantara
# Processing Record 28 of Set 1 | taonan
# Processing Record 29 of Set 1 | kaitangata
# Processing Record 30 of Set 1 | salaspils
# Processing Record 31 of Set 1 | general roca
# Processing Record 32 of Set 1 | belushya guba
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | guilin
# Processing Record 35 of Set 1 | hithadhoo
# Processing Record 36 of Set 1 | east london
# Processing Record 37 of Set 1 | port alfred
# Processing Record 38 of Set 1 | tulun
# Processing Record 39 of Set 1 | tuktoyaktuk
# Processing Record 40 of Set 1 | nizhneyansk
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 1 | cape town
# Processing Record 42 of Set 1 | aragona
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | yangcun
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | monterey
# Processing Record 48 of Set 1 | uusikaupunki
# Processing Record 49 of Set 1 | nanortalik
# Processing Record 50 of Set 1 | zhigansk
# Processing Record 1 of Set 2 | codrington
# Processing Record 2 of Set 2 | airai
# Processing Record 3 of Set 2 | sebezh
# Processing Record 4 of Set 2 | lufilufi
# Processing Record 5 of Set 2 | barentsburg
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 2 | kapaa
# Processing Record 7 of Set 2 | port macquarie
# Processing Record 8 of Set 2 | vostochnyy
# Processing Record 9 of Set 2 | dien bien
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 2 | butaritari
# Processing Record 11 of Set 2 | molchanovo
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | taolanaro
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | chuy
# Processing Record 16 of Set 2 | sur
# Processing Record 17 of Set 2 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 2 | fortuna
# Processing Record 19 of Set 2 | saint-pierre
# Processing Record 20 of Set 2 | tumannyy
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 2 | leningradskiy
# Processing Record 22 of Set 2 | port elizabeth
# Processing Record 23 of Set 2 | vaini
# Processing Record 24 of Set 2 | khatanga
# Processing Record 25 of Set 2 | kutum
# Processing Record 26 of Set 2 | klaksvik
# Processing Record 27 of Set 2 | san cristobal
# Processing Record 28 of Set 2 | mar del plata
# Processing Record 29 of Set 2 | paradwip
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 2 | whitianga
# Processing Record 31 of Set 2 | chapais
# Processing Record 32 of Set 2 | aksu
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | sinkat
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | ponta do sol
# Processing Record 37 of Set 2 | namibe
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | cap malheureux
# Processing Record 40 of Set 2 | westport
# Processing Record 41 of Set 2 | itarema
# Processing Record 42 of Set 2 | gediz
# Processing Record 43 of Set 2 | grand river south east
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 2 | bolungarvik
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | lavrentiya
# Processing Record 47 of Set 2 | impfondo
# Processing Record 48 of Set 2 | kodiak
# Processing Record 49 of Set 2 | bukachacha
# Processing Record 50 of Set 2 | kamenskoye
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 3 | mount isa
# Processing Record 2 of Set 3 | bosaso
# Processing Record 3 of Set 3 | amderma
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 3 | samarai
# Processing Record 5 of Set 3 | nurota
# Processing Record 6 of Set 3 | castro
# Processing Record 7 of Set 3 | yumen
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | bredasdorp
# Processing Record 10 of Set 3 | talnakh
# Processing Record 11 of Set 3 | ojinaga
# Processing Record 12 of Set 3 | longyearbyen
# Processing Record 13 of Set 3 | iskateley
# Processing Record 14 of Set 3 | salina cruz
# Processing Record 15 of Set 3 | port hardy
# Processing Record 16 of Set 3 | pilar
# Processing Record 17 of Set 3 | bambous virieux
# Processing Record 18 of Set 3 | dover
# Processing Record 19 of Set 3 | pingliang
# Processing Record 20 of Set 3 | sheridan
# Processing Record 21 of Set 3 | passo de camaragibe
# Processing Record 22 of Set 3 | egvekinot
# Processing Record 23 of Set 3 | guozhen
# Processing Record 24 of Set 3 | rancho palos verdes
# Processing Record 25 of Set 3 | ajaccio
# Processing Record 26 of Set 3 | yanam
# Processing Record 27 of Set 3 | kyzyl-suu
# Processing Record 28 of Set 3 | narsaq
# Processing Record 29 of Set 3 | cayambe
# Processing Record 30 of Set 3 | joppatowne
# Processing Record 31 of Set 3 | caravelas
# Processing Record 32 of Set 3 | el wasta
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 3 | aasiaat
# Processing Record 34 of Set 3 | dingle
# Processing Record 35 of Set 3 | san policarpo
# Processing Record 36 of Set 3 | mount gambier
# Processing Record 37 of Set 3 | svetlyy
# Processing Record 38 of Set 3 | erenhot
# Processing Record 39 of Set 3 | panguipulli
# Processing Record 40 of Set 3 | ust-tsilma
# Processing Record 41 of Set 3 | ous
# Processing Record 42 of Set 3 | mys shmidta
# 'coord'
# City not found. Skipping...
# Processing Record 43 of Set 3 | presidente medici
# Processing Record 44 of Set 3 | loma bonita
# Processing Record 45 of Set 3 | mahebourg
# Processing Record 46 of Set 3 | itaqui
# Processing Record 47 of Set 3 | durres
# Processing Record 48 of Set 3 | barrow
# Processing Record 49 of Set 3 | arraial do cabo
# Processing Record 50 of Set 3 | cherskiy
# Processing Record 1 of Set 4 | tasiilaq
# Processing Record 2 of Set 4 | nome
# Processing Record 3 of Set 4 | carnarvon
# Processing Record 4 of Set 4 | berlevag
# Processing Record 5 of Set 4 | ahipara
# Processing Record 6 of Set 4 | kunda
# Processing Record 7 of Set 4 | chokurdakh
# Processing Record 8 of Set 4 | povarovo
# Processing Record 9 of Set 4 | chara
# Processing Record 10 of Set 4 | shimanovsk
# Processing Record 11 of Set 4 | jiexiu
# Processing Record 12 of Set 4 | monrovia
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | troina
# Processing Record 15 of Set 4 | saint george
# Processing Record 16 of Set 4 | hegang
# Processing Record 17 of Set 4 | bengkulu
# Processing Record 18 of Set 4 | sisimiut
# Processing Record 19 of Set 4 | balkanabat
# Processing Record 20 of Set 4 | esperance
# Processing Record 21 of Set 4 | san jose de guanipa
# Processing Record 22 of Set 4 | nchelenge
# Processing Record 23 of Set 4 | fonte boa
# Processing Record 24 of Set 4 | synya
# Processing Record 25 of Set 4 | hihifo
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 4 | upernavik
# Processing Record 27 of Set 4 | santa cruz del norte
# Processing Record 28 of Set 4 | torbay
# Processing Record 29 of Set 4 | san quintin
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | muddebihal
# Processing Record 32 of Set 4 | kailua
# Processing Record 33 of Set 4 | bay roberts
# Processing Record 34 of Set 4 | ust-kamchatsk
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 4 | anahuac
# Processing Record 36 of Set 4 | flinders
# Processing Record 37 of Set 4 | puerto ayacucho
# Processing Record 38 of Set 4 | santa fe
# Processing Record 39 of Set 4 | guerrero negro
# Processing Record 40 of Set 4 | abu kamal
# Processing Record 41 of Set 4 | koshurnikovo
# Processing Record 42 of Set 4 | saint-augustin
# Processing Record 43 of Set 4 | roald
# Processing Record 44 of Set 4 | sitka
# Processing Record 45 of Set 4 | amga
# Processing Record 46 of Set 4 | trinidad
# Processing Record 47 of Set 4 | yazman
# Processing Record 48 of Set 4 | gotsu
# Processing Record 49 of Set 4 | tevaitoa
# Processing Record 50 of Set 4 | korla
# Processing Record 1 of Set 5 | salym
# Processing Record 2 of Set 5 | hamilton
# Processing Record 3 of Set 5 | littleton
# Processing Record 4 of Set 5 | vila velha
# Processing Record 5 of Set 5 | clyde river
# Processing Record 6 of Set 5 | tiznit
# Processing Record 7 of Set 5 | namatanai
# Processing Record 8 of Set 5 | baykit
# Processing Record 9 of Set 5 | metro
# Processing Record 10 of Set 5 | te anau
# Processing Record 11 of Set 5 | avera
# Processing Record 12 of Set 5 | saint combs
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 5 | lubango
# Processing Record 14 of Set 5 | puerto escondido
# Processing Record 15 of Set 5 | scarborough
# Processing Record 16 of Set 5 | tiksi
# Processing Record 17 of Set 5 | san patricio
# Processing Record 18 of Set 5 | alihe
# Processing Record 19 of Set 5 | ilhabela
# Processing Record 20 of Set 5 | hasaki
# Processing Record 21 of Set 5 | jinhua
# Processing Record 22 of Set 5 | nyurba
# Processing Record 23 of Set 5 | ugoofaaru
# Processing Record 24 of Set 5 | vestmannaeyjar
# Processing Record 25 of Set 5 | kayattar
# Processing Record 26 of Set 5 | kalmunai
# Processing Record 27 of Set 5 | pevek
# Processing Record 28 of Set 5 | barroualie
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 5 | walvis bay
# Processing Record 30 of Set 5 | broome
# Processing Record 31 of Set 5 | portland
# Processing Record 32 of Set 5 | lukovetskiy
# Processing Record 33 of Set 5 | provideniya
# Processing Record 34 of Set 5 | umea
# Processing Record 35 of Set 5 | kilrush
# Processing Record 36 of Set 5 | kondinskoye
# Processing Record 37 of Set 5 | antsohihy
# Processing Record 38 of Set 5 | touros
# Processing Record 39 of Set 5 | ulladulla
# Processing Record 40 of Set 5 | kuandian
# Processing Record 41 of Set 5 | ostersund
# Processing Record 42 of Set 5 | nouadhibou
# Processing Record 43 of Set 5 | balbalan
# Processing Record 44 of Set 5 | georgetown
# Processing Record 45 of Set 5 | kavieng
# Processing Record 46 of Set 5 | oktyabrskiy
# Processing Record 47 of Set 5 | tarudant
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 5 | birao
# Processing Record 49 of Set 5 | bud
# Processing Record 50 of Set 5 | dwarka
# Processing Record 1 of Set 6 | colares
# Processing Record 2 of Set 6 | beyneu
# Processing Record 3 of Set 6 | amos
# Processing Record 4 of Set 6 | taksimo
# Processing Record 5 of Set 6 | ancud
# Processing Record 6 of Set 6 | saint-francois
# Processing Record 7 of Set 6 | elizabeth city
# Processing Record 8 of Set 6 | malwan
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 6 | tallahassee
# Processing Record 10 of Set 6 | bonthe
# Processing Record 11 of Set 6 | chicama
# Processing Record 12 of Set 6 | kysyl-syr
# Processing Record 13 of Set 6 | altos del rosario
# Processing Record 14 of Set 6 | diffa
# Processing Record 15 of Set 6 | hefei
# Processing Record 16 of Set 6 | talara
# Processing Record 17 of Set 6 | loutros
# Processing Record 18 of Set 6 | lokosovo
# Processing Record 19 of Set 6 | goma
# Processing Record 20 of Set 6 | rajula
# Processing Record 21 of Set 6 | victoria
# Processing Record 22 of Set 6 | bambamarca
# Processing Record 23 of Set 6 | poum
# Processing Record 24 of Set 6 | mizpe ramon
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 6 | hidalgo
# Processing Record 26 of Set 6 | menongue
# Processing Record 27 of Set 6 | rungata
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 6 | muskogee
# Processing Record 29 of Set 6 | beloha
# Processing Record 30 of Set 6 | mattru
# Processing Record 31 of Set 6 | faya
# Processing Record 32 of Set 6 | marcona
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 6 | newport
# Processing Record 34 of Set 6 | fairbanks
# Processing Record 35 of Set 6 | tam ky
# Processing Record 36 of Set 6 | mukhtolovo
# Processing Record 37 of Set 6 | komsomolskiy
# Processing Record 38 of Set 6 | scottsburgh
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 6 | brooks
# Processing Record 40 of Set 6 | santa fe do sul
# Processing Record 41 of Set 6 | dixon
# Processing Record 42 of Set 6 | fort nelson
# Processing Record 43 of Set 6 | agen
# Processing Record 44 of Set 6 | bagdarin
# Processing Record 45 of Set 6 | znin
# Processing Record 46 of Set 6 | rylsk
# Processing Record 47 of Set 6 | sorab
# Processing Record 48 of Set 6 | bluff
# Processing Record 49 of Set 6 | alyangula
# Processing Record 50 of Set 6 | dunedin
# Processing Record 1 of Set 7 | pafos
# Processing Record 2 of Set 7 | kudat
# Processing Record 3 of Set 7 | makinsk
# Processing Record 4 of Set 7 | rantauprapat
# Processing Record 5 of Set 7 | falmouth
# Processing Record 6 of Set 7 | golden
# Processing Record 7 of Set 7 | hearst
# Processing Record 8 of Set 7 | dicabisagan
# Processing Record 9 of Set 7 | rundu
# Processing Record 10 of Set 7 | barwani
# Processing Record 11 of Set 7 | pangoa
# Processing Record 12 of Set 7 | chodavaram
# Processing Record 13 of Set 7 | lahuachaca
# Processing Record 14 of Set 7 | bang saphan
# Processing Record 15 of Set 7 | nanakuli
# Processing Record 16 of Set 7 | aswan
# Processing Record 17 of Set 7 | warmbad
# Processing Record 18 of Set 7 | bandarbeyla
# Processing Record 19 of Set 7 | guiratinga
# Processing Record 20 of Set 7 | makakilo city
# Processing Record 21 of Set 7 | furstenwalde
# Processing Record 22 of Set 7 | yankton
# Processing Record 23 of Set 7 | kazalinsk
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 7 | teshie
# Processing Record 25 of Set 7 | mehamn
# Processing Record 26 of Set 7 | taburi
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 7 | karkaralinsk
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 7 | altamont
# Processing Record 29 of Set 7 | merauke
# Processing Record 30 of Set 7 | lagoa
# Processing Record 31 of Set 7 | atagay
# Processing Record 32 of Set 7 | at-bashi
# Processing Record 33 of Set 7 | thiers
# Processing Record 34 of Set 7 | mindelo
# Processing Record 35 of Set 7 | gizo
# Processing Record 36 of Set 7 | haines junction
# Processing Record 37 of Set 7 | sharan
# Processing Record 38 of Set 7 | arlit
# Processing Record 39 of Set 7 | tchollire
# Processing Record 40 of Set 7 | vadso
# Processing Record 41 of Set 7 | castlemaine
# Processing Record 42 of Set 7 | daru
# Processing Record 43 of Set 7 | kachug
# Processing Record 44 of Set 7 | grindavik
# Processing Record 45 of Set 7 | champerico
# Processing Record 46 of Set 7 | galveston
# Processing Record 47 of Set 7 | sao joao da barra
# Processing Record 48 of Set 7 | miraflores
# Processing Record 49 of Set 7 | umba
# Processing Record 50 of Set 7 | coxim
# Processing Record 1 of Set 8 | talcahuano
# Processing Record 2 of Set 8 | lasa
# Processing Record 3 of Set 8 | hirado
# Processing Record 4 of Set 8 | ayios matthaios
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 8 | utete
# Processing Record 6 of Set 8 | ilulissat
# Processing Record 7 of Set 8 | tambura
# Processing Record 8 of Set 8 | minuwangoda
# Processing Record 9 of Set 8 | vao
# Processing Record 10 of Set 8 | bagli
# Processing Record 11 of Set 8 | mantua
# Processing Record 12 of Set 8 | baboua
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 8 | inuvik
# Processing Record 14 of Set 8 | hualmay
# Processing Record 15 of Set 8 | pizarro
# Processing Record 16 of Set 8 | tautira
# Processing Record 17 of Set 8 | dayong
# Processing Record 18 of Set 8 | soufriere
# Processing Record 19 of Set 8 | evensk
# Processing Record 20 of Set 8 | linjiang
# Processing Record 21 of Set 8 | kwinana
# Processing Record 22 of Set 8 | sao filipe
# Processing Record 23 of Set 8 | witu
# Processing Record 24 of Set 8 | cockburn town
# Processing Record 25 of Set 8 | vaitupu
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 8 | karratha
# Processing Record 27 of Set 8 | vila franca do campo
# Processing Record 28 of Set 8 | chissamba
# Processing Record 29 of Set 8 | kampot
# Processing Record 30 of Set 8 | lompoc
# Processing Record 31 of Set 8 | hami
# Processing Record 32 of Set 8 | linxia
# Processing Record 33 of Set 8 | soyo
# Processing Record 34 of Set 8 | sobolevo
# Processing Record 35 of Set 8 | rio gallegos
# Processing Record 36 of Set 8 | hambantota
# Processing Record 37 of Set 8 | umm kaddadah
# Processing Record 38 of Set 8 | cabo san lucas
# Processing Record 39 of Set 8 | aquiraz
# Processing Record 40 of Set 8 | tocopilla
# Processing Record 41 of Set 8 | iqaluit
# Processing Record 42 of Set 8 | harper
# Processing Record 43 of Set 8 | ferrol
# Processing Record 44 of Set 8 | mayumba
# Processing Record 45 of Set 8 | buin
# Processing Record 46 of Set 8 | atar
# Processing Record 47 of Set 8 | belyy yar
# Processing Record 48 of Set 8 | ruidoso
# Processing Record 49 of Set 8 | burica
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 8 | eydhafushi
# Processing Record 1 of Set 9 | zhanaozen
# Processing Record 2 of Set 9 | mehran
# Processing Record 3 of Set 9 | kloulklubed
# Processing Record 4 of Set 9 | tucumcari
# Processing Record 5 of Set 9 | celestun
# Processing Record 6 of Set 9 | qaqortoq
# Processing Record 7 of Set 9 | bajo baudo
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 9 | terney
# Processing Record 9 of Set 9 | barra patuca
# Processing Record 10 of Set 9 | tabialan
# 'coord'
# City not found. Skipping...
# Processing Record 11 of Set 9 | nokaneng
# Processing Record 12 of Set 9 | awbari
# Processing Record 13 of Set 9 | bac lieu
# Processing Record 14 of Set 9 | norman wells
# Processing Record 15 of Set 9 | devonport
# Processing Record 16 of Set 9 | molde
# Processing Record 17 of Set 9 | la ronge
# Processing Record 18 of Set 9 | seoul
# Processing Record 19 of Set 9 | sioux lookout
# Processing Record 20 of Set 9 | bandar-e lengeh
# Processing Record 21 of Set 9 | emerald
# Processing Record 22 of Set 9 | dangriga
# Processing Record 23 of Set 9 | college
# Processing Record 24 of Set 9 | salalah
# Processing Record 25 of Set 9 | ballina
# Processing Record 26 of Set 9 | cordoba
# Processing Record 27 of Set 9 | attawapiskat
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 9 | pouebo
# Processing Record 29 of Set 9 | havelock
# Processing Record 30 of Set 9 | umzimvubu
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 9 | llanes
# Processing Record 32 of Set 9 | ondangwa
# Processing Record 33 of Set 9 | hobyo
# Processing Record 34 of Set 9 | nikel
# Processing Record 35 of Set 9 | mananara
# Processing Record 36 of Set 9 | hofn
# Processing Record 37 of Set 9 | pisco
# Processing Record 38 of Set 9 | bara
# Processing Record 39 of Set 9 | shchelyayur
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 9 | sentyabrskiy
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 9 | neiafu
# Processing Record 42 of Set 9 | gillette
# Processing Record 43 of Set 9 | nakamura
# Processing Record 44 of Set 9 | praia da vitoria
# Processing Record 45 of Set 9 | taltal
# Processing Record 46 of Set 9 | atasu
# Processing Record 47 of Set 9 | ardistan
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 9 | yagodnoye
# Processing Record 49 of Set 9 | tilichiki
# Processing Record 50 of Set 9 | cortez
# Processing Record 1 of Set 10 | aksha
# Processing Record 2 of Set 10 | pasighat
# Processing Record 3 of Set 10 | dire
# Processing Record 4 of Set 10 | dutse
# Processing Record 5 of Set 10 | hervey bay
# Processing Record 6 of Set 10 | qasigiannguit
# Processing Record 7 of Set 10 | bahar
# Processing Record 8 of Set 10 | kiunga
# Processing Record 9 of Set 10 | altay
# Processing Record 10 of Set 10 | bereda
# Processing Record 11 of Set 10 | abbeville
# Processing Record 12 of Set 10 | kyakhta
# Processing Record 13 of Set 10 | coihaique
# Processing Record 14 of Set 10 | babu
# Processing Record 15 of Set 10 | dhidhdhoo
# Processing Record 16 of Set 10 | kamloops
# Processing Record 17 of Set 10 | kruisfontein
# Processing Record 18 of Set 10 | souillac
# Processing Record 19 of Set 10 | biak
# Processing Record 20 of Set 10 | gamba
# Processing Record 21 of Set 10 | farso
# Processing Record 22 of Set 10 | luderitz
# Processing Record 23 of Set 10 | nantucket
# Processing Record 24 of Set 10 | salinopolis
# Processing Record 25 of Set 10 | charlottetown
# Processing Record 26 of Set 10 | leiyang
# Processing Record 27 of Set 10 | christchurch
# Processing Record 28 of Set 10 | houma
# Processing Record 29 of Set 10 | sri aman
# Processing Record 30 of Set 10 | labuhan
# Processing Record 31 of Set 10 | kuala terengganu
# Processing Record 32 of Set 10 | gorontalo
# Processing Record 33 of Set 10 | eidfjord
# Processing Record 34 of Set 10 | sucua
# Processing Record 35 of Set 10 | porto velho
# Processing Record 36 of Set 10 | buala
# Processing Record 37 of Set 10 | wanning
# Processing Record 38 of Set 10 | ostrovnoy
# Processing Record 39 of Set 10 | mon
# Processing Record 40 of Set 10 | ganzhou
# Processing Record 41 of Set 10 | garden city
# Processing Record 42 of Set 10 | nemuro
# Processing Record 43 of Set 10 | coquimbo
# Processing Record 44 of Set 10 | pangnirtung
# Processing Record 45 of Set 10 | asau
# Processing Record 46 of Set 10 | mashhad
# Processing Record 47 of Set 10 | severo-kurilsk
# Processing Record 48 of Set 10 | ulcinj
# Processing Record 49 of Set 10 | charlestown
# Processing Record 50 of Set 10 | bababe
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 11 | liverpool
# Processing Record 3 of Set 11 | cilegon
# Processing Record 4 of Set 11 | catamarca
# Processing Record 5 of Set 11 | anage
# Processing Record 6 of Set 11 | fukue
# Processing Record 7 of Set 11 | berdigestyakh
# Processing Record 8 of Set 11 | falealupo
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 11 | omsukchan
# Processing Record 10 of Set 11 | boda
# Processing Record 11 of Set 11 | tsihombe
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 11 | bubaque
# Processing Record 13 of Set 11 | nuuk
# Processing Record 14 of Set 11 | saint anthony
# Processing Record 15 of Set 11 | fort saint john
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 11 | carutapera
# Processing Record 17 of Set 11 | san carlos de bariloche
# Processing Record 18 of Set 11 | batouri
# Processing Record 19 of Set 11 | laguna
# Processing Record 20 of Set 11 | zyryanka
# Processing Record 21 of Set 11 | belfast
# Processing Record 22 of Set 11 | bima
# Processing Record 23 of Set 11 | verkhoyansk
# Processing Record 24 of Set 11 | alekseyevka
# Processing Record 25 of Set 11 | tres arroyos
# Processing Record 26 of Set 11 | maridi
# Processing Record 27 of Set 11 | porbandar
# Processing Record 28 of Set 11 | abu samrah
# Processing Record 29 of Set 11 | ola
# Processing Record 30 of Set 11 | starodub
# Processing Record 31 of Set 11 | rock springs
# Processing Record 32 of Set 11 | redcliffe
# Processing Record 33 of Set 11 | bria
# Processing Record 34 of Set 11 | arona
# Processing Record 35 of Set 11 | skotterud
# Processing Record 36 of Set 11 | port lincoln
# Processing Record 37 of Set 11 | chagda
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 11 | puerto pinasco
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 11 | port blair
# Processing Record 40 of Set 11 | la paz
# Processing Record 41 of Set 11 | magelang
# Processing Record 42 of Set 11 | vila
# Processing Record 43 of Set 11 | rio grande
# Processing Record 44 of Set 11 | utiroa
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 11 | misratah
# Processing Record 46 of Set 11 | adrar
# Processing Record 47 of Set 11 | husavik
# Processing Record 48 of Set 11 | moose factory
# Processing Record 49 of Set 11 | meadow lake
# Processing Record 50 of Set 11 | kudahuvadhoo
# Processing Record 1 of Set 12 | constitucion
# Processing Record 2 of Set 12 | alnavar
# Processing Record 3 of Set 12 | varnavino
# Processing Record 4 of Set 12 | daxian
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 12 | labutta
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 12 | yar-sale
# Processing Record 7 of Set 12 | thai binh
# Processing Record 8 of Set 12 | kerema
# Processing Record 9 of Set 12 | novoagansk
# Processing Record 10 of Set 12 | marawi
# Processing Record 11 of Set 12 | dourbali
# Processing Record 12 of Set 12 | coahuayana
# Processing Record 13 of Set 12 | balikpapan
# Processing Record 14 of Set 12 | boa vista
# Processing Record 15 of Set 12 | neyshabur
# Processing Record 16 of Set 12 | moreira sales
# Processing Record 17 of Set 12 | cayenne
# Processing Record 18 of Set 12 | beisfjord
# Processing Record 19 of Set 12 | marovoay
# Processing Record 20 of Set 12 | sar-e pul
# Processing Record 21 of Set 12 | fare
# Processing Record 22 of Set 12 | gainesville
# Processing Record 23 of Set 12 | murwillumbah
# Processing Record 24 of Set 12 | sabang
# Processing Record 25 of Set 12 | chuncheng
# Processing Record 26 of Set 12 | swellendam
# Processing Record 27 of Set 12 | russell
# Processing Record 28 of Set 12 | kathu
# Processing Record 29 of Set 12 | mullaitivu
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 12 | henzada
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 12 | abu dhabi
# Processing Record 32 of Set 12 | rapid city
# Processing Record 33 of Set 12 | ode
# Processing Record 34 of Set 12 | albanel
# Processing Record 35 of Set 12 | kamaishi
# Processing Record 36 of Set 12 | andilamena
# Processing Record 37 of Set 12 | ryki
# Processing Record 38 of Set 12 | carauari
# Processing Record 39 of Set 12 | ksenyevka
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 12 | tir pol
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 12 | bitung
# Processing Record 42 of Set 12 | hovd
# Processing Record 43 of Set 12 | alta floresta
# Processing Record 44 of Set 12 | seymchan
# Processing Record 45 of Set 12 | alofi
# Processing Record 46 of Set 12 | sorland
# Processing Record 47 of Set 12 | sao miguel
# Processing Record 48 of Set 12 | nanyang
# Processing Record 49 of Set 12 | toliary
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 12 | palmer
# Processing Record 1 of Set 13 | bay city
# Processing Record 2 of Set 13 | chuguyevka
# Processing Record 3 of Set 13 | micheweni
# Processing Record 4 of Set 13 | opuwo
# Processing Record 5 of Set 13 | ust-maya
# Processing Record 6 of Set 13 | ngunguru
# Processing Record 7 of Set 13 | temaraia
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 13 | shakawe
# Processing Record 9 of Set 13 | vardo
# Processing Record 10 of Set 13 | belawan
# Processing Record 11 of Set 13 | luancheng
# Processing Record 12 of Set 13 | rassvet
# Processing Record 13 of Set 13 | mutsamudu
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 13 | cabedelo
# Processing Record 15 of Set 13 | beroroha
# Processing Record 16 of Set 13 | necochea
# Processing Record 17 of Set 13 | tual
# Processing Record 18 of Set 13 | brigantine
# Processing Record 19 of Set 13 | verkhnevilyuysk
# Processing Record 20 of Set 13 | bibiani
# Processing Record 21 of Set 13 | las vegas
# Processing Record 22 of Set 13 | tongling
# Processing Record 23 of Set 13 | eirunepe
# Processing Record 24 of Set 13 | ondorhaan
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 13 | san luis
# Processing Record 26 of Set 13 | fasa
# Processing Record 27 of Set 13 | mwinilunga
# Processing Record 28 of Set 13 | uray
# Processing Record 29 of Set 13 | myitkyina
# Processing Record 30 of Set 13 | adolfo lopez mateos
# Processing Record 31 of Set 13 | anadyr
# Processing Record 32 of Set 13 | junin
# Processing Record 33 of Set 13 | teguise
# Processing Record 34 of Set 13 | hebi
# Processing Record 35 of Set 13 | hurghada
# Processing Record 36 of Set 13 | vyshkov
# Processing Record 37 of Set 13 | kyra
# Processing Record 38 of Set 13 | saldanha
# Processing Record 39 of Set 13 | excelsior springs
# Processing Record 40 of Set 13 | santa cruz de tenerife
# Processing Record 41 of Set 13 | kisangani
# Processing Record 42 of Set 13 | grafton
# Processing Record 43 of Set 13 | rosaryville
# Processing Record 44 of Set 13 | parnamirim
# Processing Record 45 of Set 13 | kohat
# Processing Record 46 of Set 13 | brae
# Processing Record 47 of Set 13 | dawei
# Processing Record 48 of Set 13 | kjollefjord
# Processing Record 49 of Set 13 | lolua
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 13 | hirara
# Processing Record 1 of Set 14 | moerai
# Processing Record 2 of Set 14 | kang
# Processing Record 3 of Set 14 | nova ushytsya
# Processing Record 4 of Set 14 | divnomorskoye
# Processing Record 5 of Set 14 | victor harbor
# Processing Record 6 of Set 14 | shenjiamen
# Processing Record 7 of Set 14 | paamiut
# Processing Record 8 of Set 14 | rocha
# Processing Record 9 of Set 14 | chahal
# Processing Record 10 of Set 14 | naze
# Processing Record 11 of Set 14 | amahai
# Processing Record 12 of Set 14 | sumter
# Processing Record 13 of Set 14 | ishigaki
# Processing Record 14 of Set 14 | santa cruz
# Processing Record 15 of Set 14 | kamuli
# Processing Record 16 of Set 14 | kathmandu
# Processing Record 17 of Set 14 | santa isabel do rio negro
# Processing Record 18 of Set 14 | pervomayskoye
# Processing Record 19 of Set 14 | maicao
# Processing Record 20 of Set 14 | moron
# Processing Record 21 of Set 14 | saleaula
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 14 | matara
# Processing Record 23 of Set 14 | sao miguel do araguaia
# Processing Record 24 of Set 14 | warri
# Processing Record 25 of Set 14 | lorengau
# Processing Record 26 of Set 14 | margate
# Processing Record 27 of Set 14 | nishihara
# Processing Record 28 of Set 14 | mirnyy
# Processing Record 29 of Set 14 | camargo
# Processing Record 30 of Set 14 | tura
# Processing Record 31 of Set 14 | follonica
# Processing Record 32 of Set 14 | belmonte
# Processing Record 33 of Set 14 | samarinda
# Processing Record 34 of Set 14 | katherine
# Processing Record 35 of Set 14 | springbok
# Processing Record 36 of Set 14 | songea
# Processing Record 37 of Set 14 | campbell river
# Processing Record 38 of Set 14 | sinnamary
# Processing Record 39 of Set 14 | mahaicony
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 14 | skagastrond
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 14 | liancheng
# Processing Record 42 of Set 14 | pokaran
# Processing Record 43 of Set 14 | general pico
# Processing Record 44 of Set 14 | qandala
# Processing Record 45 of Set 14 | mixtequilla
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 14 | mrirt
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 14 | goderich
# Processing Record 48 of Set 14 | wagar
# Processing Record 49 of Set 14 | tabiauea
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 14 | werda
# Processing Record 1 of Set 15 | puerto penasco
# Processing Record 2 of Set 15 | magadi
# Processing Record 3 of Set 15 | rizhao
# Processing Record 4 of Set 15 | zarubino
# Processing Record 5 of Set 15 | gat
# Processing Record 6 of Set 15 | kavaratti
# Processing Record 7 of Set 15 | albina
# Processing Record 8 of Set 15 | san jose
# Processing Record 9 of Set 15 | nepalganj
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 15 | jalali
# Processing Record 11 of Set 15 | staraya poltavka
# Processing Record 12 of Set 15 | yunjinghong
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 15 | lithakia
# Processing Record 14 of Set 15 | the valley
# Processing Record 15 of Set 15 | saint-joseph
# Processing Record 16 of Set 15 | pareora
# Processing Record 17 of Set 15 | hwange
# Processing Record 18 of Set 15 | lincoln
# Processing Record 19 of Set 15 | koryukivka
# Processing Record 20 of Set 15 | kaeo
# Processing Record 21 of Set 15 | kaihua
# Processing Record 22 of Set 15 | nha trang
# Processing Record 23 of Set 15 | sicuani
# Processing Record 24 of Set 15 | aklavik
# Processing Record 25 of Set 15 | tarko-sale
# Processing Record 26 of Set 15 | tingi
# Processing Record 27 of Set 15 | cagayan de tawi-tawi
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 15 | tanjong karang
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 15 | redmond
# Processing Record 30 of Set 15 | birjand
# Processing Record 31 of Set 15 | khromtau
# Processing Record 32 of Set 15 | alice springs
# Processing Record 33 of Set 15 | phrai bung
# 'coord'
# City not found. Skipping...
# Processing Record 34 of Set 15 | huazolotitlan
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 15 | concepcion
# Processing Record 36 of Set 15 | acarau
# Processing Record 37 of Set 15 | fayaoue
# Processing Record 38 of Set 15 | hit
# Processing Record 39 of Set 15 | paracatu
# Processing Record 40 of Set 15 | hassleholm
# Processing Record 41 of Set 15 | sarany
# Processing Record 42 of Set 15 | innisfail
# Processing Record 43 of Set 15 | challapata
# Processing Record 44 of Set 15 | usakos
# Processing Record 45 of Set 15 | san ramon
# Processing Record 46 of Set 15 | qianguo
# Processing Record 47 of Set 15 | krasnyy chikoy
# Processing Record 48 of Set 15 | makubetsu
# Processing Record 49 of Set 15 | bam
# Processing Record 50 of Set 15 | karanganyar
# Processing Record 1 of Set 16 | queanbeyan
# Processing Record 2 of Set 16 | najran
# Processing Record 3 of Set 16 | novorudnyy
# Processing Record 4 of Set 16 | freeport
# Processing Record 5 of Set 16 | casimiro castillo
# Processing Record 6 of Set 16 | yebaishou
# Processing Record 7 of Set 16 | olafsvik
# Processing Record 8 of Set 16 | mao
# Processing Record 9 of Set 16 | pondicherry
# Processing Record 10 of Set 16 | niono
# Processing Record 11 of Set 16 | pangody
# Processing Record 12 of Set 16 | half moon bay
# Processing Record 13 of Set 16 | contamana
# Processing Record 14 of Set 16 | nakasongola
# Processing Record 15 of Set 16 | watsa
# Processing Record 16 of Set 16 | basco
# Processing Record 17 of Set 16 | maturin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Katsuura  35.1333  140.3000     48.11        55          98
# 1        Xining  36.6167  101.7667     16.83        60          58
# 2     Jamestown  42.0970  -79.2353      6.71        85          43
# 3       Kenitra  34.2610   -6.5802     62.73        63           7
# 4  Punta Arenas -53.1500  -70.9167     46.11        65         100
# 5   Port-Gentil  -0.7193    8.7815     80.76        80          99
# 6        Dikson  73.5069   80.5464      7.05        94         100
# 7        Albany  42.6001  -73.9662      6.51        55         100
# 8       Rikitea -23.1203 -134.9692     76.84        68         100
# 9     Busselton -33.6500  115.3333     87.08        45           4
#
#    Wind Speed Country Current Description
# 0       11.65      JP     overcast clouds
# 1        2.55      CN       broken clouds
# 2        1.01      US    scattered clouds
# 3        3.40      MA           clear sky
# 4        9.95      CL     overcast clouds
# 5        9.57      GA     overcast clouds
# 6       16.64      RU     overcast clouds
# 7        5.99      US     overcast clouds
# 8        6.80      PF     overcast clouds
# 9       12.55      AU           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Katsuura      JP  35.1333  140.3000     48.11        55          98
# 1        Xining      CN  36.6167  101.7667     16.83        60          58
# 2     Jamestown      US  42.0970  -79.2353      6.71        85          43
# 3       Kenitra      MA  34.2610   -6.5802     62.73        63           7
# 4  Punta Arenas      CL -53.1500  -70.9167     46.11        65         100
# 5   Port-Gentil      GA  -0.7193    8.7815     80.76        80          99
# 6        Dikson      RU  73.5069   80.5464      7.05        94         100
# 7        Albany      US  42.6001  -73.9662      6.51        55         100
# 8       Rikitea      PF -23.1203 -134.9692     76.84        68         100
# 9     Busselton      AU -33.6500  115.3333     87.08        45           4
#
#    Wind Speed Current Description
# 0       11.65     overcast clouds
# 1        2.55       broken clouds
# 2        1.01    scattered clouds
# 3        3.40           clear sky
# 4        9.95     overcast clouds
# 5        9.57     overcast clouds
# 6       16.64     overcast clouds
# 7        5.99     overcast clouds
# 8        6.80     overcast clouds
# 9       12.55           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

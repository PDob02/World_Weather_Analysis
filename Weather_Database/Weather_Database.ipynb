# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
city_data = []
print(city_data)
# Out:
# []

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ef308af85e93f02acdc1dc26269d6a14

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_description})

# If an error is experienced, skip the city.
    except Exception as e:
        print(e)
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | provideniya
# Processing Record 2 of Set 1 | vardo
# Processing Record 3 of Set 1 | palabuhanratu
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 1 | hay river
# Processing Record 5 of Set 1 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 1 | zyryanovsk
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | aykino
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | aklavik
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | sentyabrskiy
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 1 | new norfolk
# Processing Record 14 of Set 1 | eufaula
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | umm jarr
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 1 | georgetown
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | maceio
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | lebu
# Processing Record 25 of Set 1 | kruisfontein
# Processing Record 26 of Set 1 | estelle
# Processing Record 27 of Set 1 | barentsburg
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 1 | vostok
# Processing Record 29 of Set 1 | haines junction
# Processing Record 30 of Set 1 | padang
# Processing Record 31 of Set 1 | cabedelo
# Processing Record 32 of Set 1 | belushya guba
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 1 | airai
# Processing Record 34 of Set 1 | rodrigues alves
# Processing Record 35 of Set 1 | udachnyy
# Processing Record 36 of Set 1 | attawapiskat
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 1 | challapata
# Processing Record 38 of Set 1 | cherskiy
# Processing Record 39 of Set 1 | fortuna
# Processing Record 40 of Set 1 | mareeba
# Processing Record 41 of Set 1 | samarai
# Processing Record 42 of Set 1 | hobart
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | baturaja
# Processing Record 45 of Set 1 | comodoro rivadavia
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | sidhauli
# Processing Record 49 of Set 1 | grand river south east
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 1 | bathsheba
# Processing Record 1 of Set 2 | cap-aux-meules
# Processing Record 2 of Set 2 | erzin
# Processing Record 3 of Set 2 | faanui
# Processing Record 4 of Set 2 | samfya
# Processing Record 5 of Set 2 | lompoc
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | portland
# Processing Record 8 of Set 2 | pemangkat
# Processing Record 9 of Set 2 | vaitupu
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 2 | hamilton
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | milkovo
# Processing Record 13 of Set 2 | qaanaaq
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | aflu
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | luwingu
# Processing Record 19 of Set 2 | asau
# Processing Record 20 of Set 2 | potamia
# Processing Record 21 of Set 2 | lovozero
# Processing Record 22 of Set 2 | opotiki
# Processing Record 23 of Set 2 | port elizabeth
# Processing Record 24 of Set 2 | geraldton
# Processing Record 25 of Set 2 | constitucion
# Processing Record 26 of Set 2 | jacareacanga
# Processing Record 27 of Set 2 | mandali
# Processing Record 28 of Set 2 | kaduqli
# Processing Record 29 of Set 2 | solnechnyy
# Processing Record 30 of Set 2 | touros
# Processing Record 31 of Set 2 | lolua
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 2 | nikolskoye
# Processing Record 33 of Set 2 | kodiak
# Processing Record 34 of Set 2 | katsuura
# Processing Record 35 of Set 2 | najran
# Processing Record 36 of Set 2 | takoradi
# Processing Record 37 of Set 2 | talnakh
# Processing Record 38 of Set 2 | rudnogorsk
# Processing Record 39 of Set 2 | avarua
# Processing Record 40 of Set 2 | noyabrsk
# Processing Record 41 of Set 2 | east london
# Processing Record 42 of Set 2 | lagoa
# Processing Record 43 of Set 2 | pontianak
# Processing Record 44 of Set 2 | esperance
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | wewak
# Processing Record 47 of Set 2 | upernavik
# Processing Record 48 of Set 2 | palimbang
# Processing Record 49 of Set 2 | avera
# Processing Record 50 of Set 2 | butaritari
# Processing Record 1 of Set 3 | elizabeth city
# Processing Record 2 of Set 3 | verkhniye tatyshly
# Processing Record 3 of Set 3 | stornoway
# Processing Record 4 of Set 3 | moshny
# Processing Record 5 of Set 3 | namibe
# Processing Record 6 of Set 3 | kenai
# Processing Record 7 of Set 3 | corrente
# Processing Record 8 of Set 3 | gasa
# Processing Record 9 of Set 3 | la rioja
# Processing Record 10 of Set 3 | tornio
# Processing Record 11 of Set 3 | dabrowa tarnowska
# Processing Record 12 of Set 3 | jamestown
# Processing Record 13 of Set 3 | pemba
# Processing Record 14 of Set 3 | batagay-alyta
# Processing Record 15 of Set 3 | mataura
# Processing Record 16 of Set 3 | vorotynets
# Processing Record 17 of Set 3 | jagalur
# Processing Record 18 of Set 3 | kargasok
# Processing Record 19 of Set 3 | santa cruz
# Processing Record 20 of Set 3 | mgachi
# Processing Record 21 of Set 3 | salekhard
# Processing Record 22 of Set 3 | mys shmidta
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 3 | zemio
# Processing Record 24 of Set 3 | anna
# Processing Record 25 of Set 3 | nome
# Processing Record 26 of Set 3 | chokurdakh
# Processing Record 27 of Set 3 | ranong
# Processing Record 28 of Set 3 | cape canaveral
# Processing Record 29 of Set 3 | buchanan
# Processing Record 30 of Set 3 | raudeberg
# Processing Record 31 of Set 3 | ormond beach
# Processing Record 32 of Set 3 | laguna
# Processing Record 33 of Set 3 | golden rock
# 'coord'
# City not found. Skipping...
# Processing Record 34 of Set 3 | carnarvon
# Processing Record 35 of Set 3 | castro
# Processing Record 36 of Set 3 | minab
# Processing Record 37 of Set 3 | tumannyy
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 3 | bad freienwalde
# Processing Record 39 of Set 3 | yuncheng
# Processing Record 40 of Set 3 | likasi
# Processing Record 41 of Set 3 | garissa
# Processing Record 42 of Set 3 | mier
# Processing Record 43 of Set 3 | cairns
# Processing Record 44 of Set 3 | saleaula
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 3 | surgut
# Processing Record 46 of Set 3 | mildura
# Processing Record 47 of Set 3 | dingli
# Processing Record 48 of Set 3 | lethem
# Processing Record 49 of Set 3 | beloha
# Processing Record 50 of Set 3 | fairbanks
# Processing Record 1 of Set 4 | riyadh
# Processing Record 2 of Set 4 | tabiauea
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 4 | sinj
# Processing Record 4 of Set 4 | lisakovsk
# Processing Record 5 of Set 4 | mbini
# Processing Record 6 of Set 4 | bambous virieux
# Processing Record 7 of Set 4 | zemlyansk
# Processing Record 8 of Set 4 | south river
# Processing Record 9 of Set 4 | havre-saint-pierre
# Processing Record 10 of Set 4 | vila franca do campo
# Processing Record 11 of Set 4 | saskylakh
# Processing Record 12 of Set 4 | valley city
# Processing Record 13 of Set 4 | dorobantu
# Processing Record 14 of Set 4 | mergui
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 4 | lorengau
# Processing Record 16 of Set 4 | balogo
# Processing Record 17 of Set 4 | kastamonu
# Processing Record 18 of Set 4 | leningradskiy
# Processing Record 19 of Set 4 | stantsiya gorchakovo
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 4 | saint-philippe
# Processing Record 21 of Set 4 | bandarbeyla
# Processing Record 22 of Set 4 | idrinskoye
# Processing Record 23 of Set 4 | kavieng
# Processing Record 24 of Set 4 | taolanaro
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 4 | kerki
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 4 | negombo
# Processing Record 27 of Set 4 | hobyo
# Processing Record 28 of Set 4 | longyearbyen
# Processing Record 29 of Set 4 | puerto ayora
# Processing Record 30 of Set 4 | south venice
# Processing Record 31 of Set 4 | khatanga
# Processing Record 32 of Set 4 | kamenskoye
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 4 | mount isa
# Processing Record 34 of Set 4 | gananoque
# Processing Record 35 of Set 4 | tasiilaq
# Processing Record 36 of Set 4 | atbasar
# Processing Record 37 of Set 4 | gamba
# Processing Record 38 of Set 4 | praia da vitoria
# Processing Record 39 of Set 4 | thompson
# Processing Record 40 of Set 4 | coihaique
# Processing Record 41 of Set 4 | borovoy
# Processing Record 42 of Set 4 | dikson
# Processing Record 43 of Set 4 | kampene
# Processing Record 44 of Set 4 | burica
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 4 | henties bay
# Processing Record 46 of Set 4 | arraial do cabo
# Processing Record 47 of Set 4 | skibbereen
# Processing Record 48 of Set 4 | san patricio
# Processing Record 49 of Set 4 | sao filipe
# Processing Record 50 of Set 4 | naftah
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 5 | atherton
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | narsaq
# Processing Record 4 of Set 5 | cazaje
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 5 | wanaka
# Processing Record 6 of Set 5 | kirakira
# Processing Record 7 of Set 5 | santa catarina de tepehuanes
# Processing Record 8 of Set 5 | cockburn town
# Processing Record 9 of Set 5 | hilo
# Processing Record 10 of Set 5 | rawson
# Processing Record 11 of Set 5 | lander
# Processing Record 12 of Set 5 | mar del plata
# Processing Record 13 of Set 5 | gilgit
# Processing Record 14 of Set 5 | sindou
# Processing Record 15 of Set 5 | cidreira
# Processing Record 16 of Set 5 | dakar
# Processing Record 17 of Set 5 | barbar
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 5 | zvenigovo
# Processing Record 19 of Set 5 | magdalena
# Processing Record 20 of Set 5 | sumbe
# Processing Record 21 of Set 5 | verkhnyaya inta
# Processing Record 22 of Set 5 | kerchevskiy
# Processing Record 23 of Set 5 | poum
# Processing Record 24 of Set 5 | louis trichardt
# Processing Record 25 of Set 5 | westport
# Processing Record 26 of Set 5 | luderitz
# Processing Record 27 of Set 5 | mount gambier
# Processing Record 28 of Set 5 | znamenskoye
# Processing Record 29 of Set 5 | port hedland
# Processing Record 30 of Set 5 | margate
# Processing Record 31 of Set 5 | half moon bay
# Processing Record 32 of Set 5 | sucua
# Processing Record 33 of Set 5 | mahebourg
# Processing Record 34 of Set 5 | wanning
# Processing Record 35 of Set 5 | lusambo
# Processing Record 36 of Set 5 | dudinka
# Processing Record 37 of Set 5 | codrington
# Processing Record 38 of Set 5 | viseu
# Processing Record 39 of Set 5 | dukat
# Processing Record 40 of Set 5 | andenes
# Processing Record 41 of Set 5 | paamiut
# Processing Record 42 of Set 5 | kungurtug
# Processing Record 43 of Set 5 | saint-francois
# Processing Record 44 of Set 5 | severo-kurilsk
# Processing Record 45 of Set 5 | belaya gora
# Processing Record 46 of Set 5 | khandbari
# Processing Record 47 of Set 5 | jalu
# Processing Record 48 of Set 5 | hami
# Processing Record 49 of Set 5 | alofi
# Processing Record 50 of Set 5 | asvestokhorion
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 6 | dingle
# Processing Record 2 of Set 6 | athabasca
# Processing Record 3 of Set 6 | saldanha
# Processing Record 4 of Set 6 | los banos
# Processing Record 5 of Set 6 | ilebo
# Processing Record 6 of Set 6 | caravelas
# Processing Record 7 of Set 6 | marivan
# Processing Record 8 of Set 6 | bud
# Processing Record 9 of Set 6 | aleksandrov gay
# Processing Record 10 of Set 6 | marystown
# Processing Record 11 of Set 6 | gambo
# Processing Record 12 of Set 6 | masakin
# Processing Record 13 of Set 6 | bambanglipuro
# Processing Record 14 of Set 6 | strezhevoy
# Processing Record 15 of Set 6 | lima
# Processing Record 16 of Set 6 | hithadhoo
# Processing Record 17 of Set 6 | cowra
# Processing Record 18 of Set 6 | isiolo
# Processing Record 19 of Set 6 | nizhneyansk
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 6 | ruston
# Processing Record 21 of Set 6 | vilcun
# Processing Record 22 of Set 6 | ambodifototra
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 6 | jurm
# Processing Record 24 of Set 6 | yuancheng
# Processing Record 25 of Set 6 | damara
# Processing Record 26 of Set 6 | hambantota
# Processing Record 27 of Set 6 | ribeira grande
# Processing Record 28 of Set 6 | turukhansk
# Processing Record 29 of Set 6 | coquimbo
# Processing Record 30 of Set 6 | vila velha
# Processing Record 31 of Set 6 | olafsvik
# Processing Record 32 of Set 6 | botwood
# Processing Record 33 of Set 6 | port macquarie
# Processing Record 34 of Set 6 | arlit
# Processing Record 35 of Set 6 | bridlington
# Processing Record 36 of Set 6 | fowa
# Processing Record 37 of Set 6 | saint george
# Processing Record 38 of Set 6 | conceicao do araguaia
# Processing Record 39 of Set 6 | port-gentil
# Processing Record 40 of Set 6 | souillac
# Processing Record 41 of Set 6 | ilesha
# Processing Record 42 of Set 6 | kamen-rybolov
# Processing Record 43 of Set 6 | matamba
# Processing Record 44 of Set 6 | marcona
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 6 | puksoozero
# Processing Record 46 of Set 6 | mandalay
# Processing Record 47 of Set 6 | jabiru
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 6 | kaitangata
# Processing Record 49 of Set 6 | thinadhoo
# Processing Record 50 of Set 6 | doaba
# Processing Record 1 of Set 7 | salinas
# Processing Record 2 of Set 7 | lavrentiya
# Processing Record 3 of Set 7 | sokoni
# Processing Record 4 of Set 7 | yeppoon
# Processing Record 5 of Set 7 | tuatapere
# Processing Record 6 of Set 7 | ponta do sol
# Processing Record 7 of Set 7 | sisimiut
# Processing Record 8 of Set 7 | tiznit
# Processing Record 9 of Set 7 | bilibino
# Processing Record 10 of Set 7 | rocha
# Processing Record 11 of Set 7 | fjerritslev
# Processing Record 12 of Set 7 | te anau
# Processing Record 13 of Set 7 | carman
# Processing Record 14 of Set 7 | kloulklubed
# Processing Record 15 of Set 7 | louisbourg
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 7 | kijang
# Processing Record 17 of Set 7 | sinegorye
# Processing Record 18 of Set 7 | sao gabriel
# Processing Record 19 of Set 7 | quatre cocos
# Processing Record 20 of Set 7 | bengkulu
# Processing Record 21 of Set 7 | taoudenni
# Processing Record 22 of Set 7 | clyde river
# Processing Record 23 of Set 7 | iqaluit
# Processing Record 24 of Set 7 | kasongo-lunda
# Processing Record 25 of Set 7 | aguie
# Processing Record 26 of Set 7 | hirara
# Processing Record 27 of Set 7 | los llanos de aridane
# Processing Record 28 of Set 7 | yurla
# Processing Record 29 of Set 7 | grindavik
# Processing Record 30 of Set 7 | norman wells
# Processing Record 31 of Set 7 | susanville
# Processing Record 32 of Set 7 | swan river
# Processing Record 33 of Set 7 | sahawar
# Processing Record 34 of Set 7 | satitoa
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 7 | kidal
# Processing Record 36 of Set 7 | senhor do bonfim
# Processing Record 37 of Set 7 | plettenberg bay
# Processing Record 38 of Set 7 | new albany
# Processing Record 39 of Set 7 | adre
# Processing Record 40 of Set 7 | kumylzhenskaya
# Processing Record 41 of Set 7 | noblesville
# Processing Record 42 of Set 7 | shetpe
# Processing Record 43 of Set 7 | zaraza
# Processing Record 44 of Set 7 | mantua
# Processing Record 45 of Set 7 | srednekolymsk
# Processing Record 46 of Set 7 | puerto narino
# Processing Record 47 of Set 7 | manaure
# Processing Record 48 of Set 7 | bagotville
# Processing Record 49 of Set 7 | praia
# Processing Record 50 of Set 7 | grand gaube
# Processing Record 1 of Set 8 | whitehorse
# Processing Record 2 of Set 8 | independencia
# Processing Record 3 of Set 8 | krasnoselkup
# Processing Record 4 of Set 8 | labrea
# Processing Record 5 of Set 8 | chernyshevsk
# Processing Record 6 of Set 8 | boa vista
# Processing Record 7 of Set 8 | mandera
# Processing Record 8 of Set 8 | tautira
# Processing Record 9 of Set 8 | pevek
# Processing Record 10 of Set 8 | vestmannaeyjar
# Processing Record 11 of Set 8 | morant bay
# Processing Record 12 of Set 8 | acapulco
# Processing Record 13 of Set 8 | weligama
# Processing Record 14 of Set 8 | namatanai
# Processing Record 15 of Set 8 | klaksvik
# Processing Record 16 of Set 8 | naze
# Processing Record 17 of Set 8 | macomer
# Processing Record 18 of Set 8 | salalah
# Processing Record 19 of Set 8 | kartarpur
# Processing Record 20 of Set 8 | sitka
# Processing Record 21 of Set 8 | flinders
# Processing Record 22 of Set 8 | taltal
# Processing Record 23 of Set 8 | cartagena
# Processing Record 24 of Set 8 | jubayl
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 8 | nishihara
# Processing Record 26 of Set 8 | carauari
# Processing Record 27 of Set 8 | yarkovo
# Processing Record 28 of Set 8 | shimoda
# Processing Record 29 of Set 8 | muli
# Processing Record 30 of Set 8 | namtsy
# Processing Record 31 of Set 8 | kazalinsk
# 'coord'
# City not found. Skipping...
# Processing Record 32 of Set 8 | heide
# Processing Record 33 of Set 8 | vilyuysk
# Processing Record 34 of Set 8 | san cristobal
# Processing Record 35 of Set 8 | patrocinio
# Processing Record 36 of Set 8 | sindor
# Processing Record 37 of Set 8 | miracatu
# Processing Record 38 of Set 8 | netrakona
# Processing Record 39 of Set 8 | karratha
# Processing Record 40 of Set 8 | sao goncalo do sapucai
# Processing Record 41 of Set 8 | taybad
# Processing Record 42 of Set 8 | husavik
# Processing Record 43 of Set 8 | anuradhapura
# Processing Record 44 of Set 8 | puri
# Processing Record 45 of Set 8 | vao
# Processing Record 46 of Set 8 | korla
# Processing Record 47 of Set 8 | ondorhaan
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 8 | ancud
# Processing Record 49 of Set 8 | villarrica
# Processing Record 50 of Set 8 | robertsport
# Processing Record 1 of Set 9 | along
# Processing Record 2 of Set 9 | chitapur
# Processing Record 3 of Set 9 | bintulu
# Processing Record 4 of Set 9 | manokwari
# Processing Record 5 of Set 9 | ucluelet
# Processing Record 6 of Set 9 | pacific grove
# Processing Record 7 of Set 9 | yuzhno-yeniseyskiy
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 9 | pecos
# Processing Record 9 of Set 9 | mosquera
# Processing Record 10 of Set 9 | antalaha
# Processing Record 11 of Set 9 | luanda
# Processing Record 12 of Set 9 | ilulissat
# Processing Record 13 of Set 9 | inhambane
# Processing Record 14 of Set 9 | kumluca
# Processing Record 15 of Set 9 | port hardy
# Processing Record 16 of Set 9 | yar-sale
# Processing Record 17 of Set 9 | sao joao da barra
# Processing Record 18 of Set 9 | yanan
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 9 | ishigaki
# Processing Record 20 of Set 9 | pontes e lacerda
# Processing Record 21 of Set 9 | amderma
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 9 | rangapara
# Processing Record 23 of Set 9 | nola
# Processing Record 24 of Set 9 | alyangula
# Processing Record 25 of Set 9 | piacabucu
# Processing Record 26 of Set 9 | ereymentau
# Processing Record 27 of Set 9 | maxixe
# Processing Record 28 of Set 9 | yaan
# Processing Record 29 of Set 9 | rambha
# Processing Record 30 of Set 9 | camacha
# Processing Record 31 of Set 9 | kieta
# Processing Record 32 of Set 9 | altamira
# Processing Record 33 of Set 9 | meulaboh
# Processing Record 34 of Set 9 | warmbad
# Processing Record 35 of Set 9 | bukachacha
# Processing Record 36 of Set 9 | aiken
# Processing Record 37 of Set 9 | sept-iles
# Processing Record 38 of Set 9 | port lincoln
# Processing Record 39 of Set 9 | touba
# Processing Record 40 of Set 9 | adrar
# Processing Record 41 of Set 9 | melilla
# Processing Record 42 of Set 9 | merritt island
# Processing Record 43 of Set 9 | kristiansund
# Processing Record 44 of Set 9 | arco
# Processing Record 45 of Set 9 | nong khai
# Processing Record 46 of Set 9 | chagda
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 9 | kuytun
# Processing Record 48 of Set 9 | nouadhibou
# Processing Record 49 of Set 9 | oskemen
# Processing Record 50 of Set 9 | acarau
# Processing Record 1 of Set 10 | barkly west
# Processing Record 2 of Set 10 | guata
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 10 | saviese
# Processing Record 4 of Set 10 | surt
# Processing Record 5 of Set 10 | araouane
# Processing Record 6 of Set 10 | mehamn
# Processing Record 7 of Set 10 | capanema
# Processing Record 8 of Set 10 | ahipara
# Processing Record 9 of Set 10 | guiglo
# Processing Record 10 of Set 10 | pimenta bueno
# Processing Record 11 of Set 10 | broome
# Processing Record 12 of Set 10 | bodden town
# Processing Record 13 of Set 10 | vanimo
# Processing Record 14 of Set 10 | jujuy
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 10 | collierville
# Processing Record 16 of Set 10 | svetlyy
# Processing Record 17 of Set 10 | iracoubo
# Processing Record 18 of Set 10 | wuwei
# Processing Record 19 of Set 10 | oktyabrskoye
# Processing Record 20 of Set 10 | mossendjo
# Processing Record 21 of Set 10 | teguise
# Processing Record 22 of Set 10 | dubbo
# Processing Record 23 of Set 10 | emerald
# Processing Record 24 of Set 10 | grand-santi
# Processing Record 25 of Set 10 | plouzane
# Processing Record 26 of Set 10 | samusu
# 'coord'
# City not found. Skipping...
# Processing Record 27 of Set 10 | kwinana
# Processing Record 28 of Set 10 | dire
# Processing Record 29 of Set 10 | aquiraz
# Processing Record 30 of Set 10 | turmalina
# Processing Record 31 of Set 10 | opuwo
# Processing Record 32 of Set 10 | isangel
# Processing Record 33 of Set 10 | guanica
# Processing Record 34 of Set 10 | palmer
# Processing Record 35 of Set 10 | carutapera
# Processing Record 36 of Set 10 | pangoa
# Processing Record 37 of Set 10 | victoria
# Processing Record 38 of Set 10 | suntar
# Processing Record 39 of Set 10 | mrirt
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 10 | tsihombe
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 10 | zlatarica
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 10 | makakilo city
# Processing Record 43 of Set 10 | iquitos
# Processing Record 44 of Set 10 | roald
# Processing Record 45 of Set 10 | chengde
# Processing Record 46 of Set 10 | hasaki
# Processing Record 47 of Set 10 | compostela
# Processing Record 48 of Set 10 | el paso
# Processing Record 49 of Set 10 | siderno
# Processing Record 50 of Set 10 | okha
# Processing Record 1 of Set 11 | nova olinda do norte
# Processing Record 2 of Set 11 | caninde
# Processing Record 3 of Set 11 | baoning
# Processing Record 4 of Set 11 | colares
# Processing Record 5 of Set 11 | grand centre
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 11 | harper
# Processing Record 7 of Set 11 | aasiaat
# Processing Record 8 of Set 11 | ergani
# Processing Record 9 of Set 11 | velizh
# Processing Record 10 of Set 11 | antofagasta
# Processing Record 11 of Set 11 | dombarovskiy
# Processing Record 12 of Set 11 | monteagudo
# Processing Record 13 of Set 11 | matamoros
# Processing Record 14 of Set 11 | lazaro cardenas
# Processing Record 15 of Set 11 | aitape
# Processing Record 16 of Set 11 | port augusta
# Processing Record 17 of Set 11 | quesnel
# Processing Record 18 of Set 11 | saint-georges
# Processing Record 19 of Set 11 | yerofey pavlovich
# Processing Record 20 of Set 11 | ostrovnoy
# Processing Record 21 of Set 11 | katsina
# Processing Record 22 of Set 11 | san ignacio
# Processing Record 23 of Set 11 | doha
# Processing Record 24 of Set 11 | tilichiki
# Processing Record 25 of Set 11 | saravan
# Processing Record 26 of Set 11 | yulara
# Processing Record 27 of Set 11 | torbay
# Processing Record 28 of Set 11 | camacupa
# Processing Record 29 of Set 11 | la aldea
# Processing Record 30 of Set 11 | zhezkazgan
# Processing Record 31 of Set 11 | porbandar
# Processing Record 32 of Set 11 | colonia
# Processing Record 33 of Set 11 | navahrudak
# Processing Record 34 of Set 11 | ust-bolsheretsk
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 11 | chimbote
# Processing Record 36 of Set 11 | malwan
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 11 | abu kamal
# Processing Record 38 of Set 11 | inderborskiy
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 11 | komsomolskiy
# Processing Record 40 of Set 11 | nanortalik
# Processing Record 41 of Set 11 | noshiro
# Processing Record 42 of Set 11 | la chapelle-sur-erdre
# Processing Record 43 of Set 11 | vilhena
# Processing Record 44 of Set 11 | floro
# Processing Record 45 of Set 11 | morondava
# Processing Record 46 of Set 11 | san quintin
# Processing Record 47 of Set 11 | chapais
# Processing Record 48 of Set 11 | nabire
# Processing Record 49 of Set 11 | magadan
# Processing Record 50 of Set 11 | phulji
# Processing Record 1 of Set 12 | mayo
# Processing Record 2 of Set 12 | lipari
# Processing Record 3 of Set 12 | mocambique
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 12 | punta alta
# Processing Record 5 of Set 12 | san carlos de bariloche
# Processing Record 6 of Set 12 | port-cartier
# Processing Record 7 of Set 12 | yazoo city
# Processing Record 8 of Set 12 | mastic beach
# Processing Record 9 of Set 12 | meyungs
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 12 | puerto gaitan
# Processing Record 11 of Set 12 | ystad
# Processing Record 12 of Set 12 | general roca
# Processing Record 13 of Set 12 | sao felix do xingu
# Processing Record 14 of Set 12 | saint-joseph
# Processing Record 15 of Set 12 | sorvag
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 12 | ischia
# Processing Record 17 of Set 12 | la ronge
# Processing Record 18 of Set 12 | zalantun
# Processing Record 19 of Set 12 | sakakah
# Processing Record 20 of Set 12 | nyurba
# Processing Record 21 of Set 12 | consuegra
# Processing Record 22 of Set 12 | trairi
# Processing Record 23 of Set 12 | edd
# Processing Record 24 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 12 | pa sang
# Processing Record 26 of Set 12 | costa rica
# Processing Record 27 of Set 12 | cabo san lucas
# Processing Record 28 of Set 12 | sofrino
# Processing Record 29 of Set 12 | itarema
# Processing Record 30 of Set 12 | honiara
# Processing Record 31 of Set 12 | akyab
# Processing Record 32 of Set 12 | jinchengjiang
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 12 | baykit
# Processing Record 34 of Set 12 | batemans bay
# Processing Record 35 of Set 12 | hualmay
# Processing Record 36 of Set 12 | koslan
# Processing Record 37 of Set 12 | peniche
# Processing Record 38 of Set 12 | marawi
# Processing Record 39 of Set 12 | faya
# Processing Record 40 of Set 12 | flin flon
# Processing Record 41 of Set 12 | yei
# Processing Record 42 of Set 12 | atar
# Processing Record 43 of Set 12 | lugui
# Processing Record 44 of Set 12 | mosalsk
# Processing Record 45 of Set 12 | broken hill
# Processing Record 46 of Set 12 | mindelo
# Processing Record 47 of Set 12 | dalvik
# Processing Record 48 of Set 12 | ondjiva
# Processing Record 49 of Set 12 | preston
# Processing Record 50 of Set 12 | menongue
# Processing Record 1 of Set 13 | wenling
# Processing Record 2 of Set 13 | kainouryion
# Processing Record 3 of Set 13 | jaciara
# Processing Record 4 of Set 13 | bonthe
# Processing Record 5 of Set 13 | cedar city
# Processing Record 6 of Set 13 | tripoli
# Processing Record 7 of Set 13 | seddon
# Processing Record 8 of Set 13 | lukovetskiy
# Processing Record 9 of Set 13 | namanyere
# Processing Record 10 of Set 13 | yeniseysk
# Processing Record 11 of Set 13 | tabialan
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 13 | kyra
# Processing Record 13 of Set 13 | leh
# Processing Record 14 of Set 13 | pauini
# Processing Record 15 of Set 13 | egvekinot
# Processing Record 16 of Set 13 | pisco
# Processing Record 17 of Set 13 | treinta y tres
# Processing Record 18 of Set 13 | kohlu
# Processing Record 19 of Set 13 | saint-pierre
# Processing Record 20 of Set 13 | tapaua
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 13 | curup
# Processing Record 22 of Set 13 | summerville
# Processing Record 23 of Set 13 | zolotinka
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 13 | biltine
# Processing Record 25 of Set 13 | kaniama
# Processing Record 26 of Set 13 | denizli
# Processing Record 27 of Set 13 | laela
# Processing Record 28 of Set 13 | kingman
# Processing Record 29 of Set 13 | mirnyy
# Processing Record 30 of Set 13 | mogadishu
# Processing Record 31 of Set 13 | outjo
# Processing Record 32 of Set 13 | arak
# Processing Record 33 of Set 13 | kortkeros
# Processing Record 34 of Set 13 | pajan
# Processing Record 35 of Set 13 | yerbogachen
# Processing Record 36 of Set 13 | palmares do sul
# Processing Record 37 of Set 13 | metro
# Processing Record 38 of Set 13 | zyryanka
# Processing Record 39 of Set 13 | mayor pablo lagerenza
# Processing Record 40 of Set 13 | galgani
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 13 | nhamunda
# Processing Record 42 of Set 13 | atka
# 'coord'
# City not found. Skipping...
# Processing Record 43 of Set 13 | balkanabat
# Processing Record 44 of Set 13 | nizhniy odes
# Processing Record 45 of Set 13 | chinsali
# Processing Record 46 of Set 13 | huaral
# Processing Record 47 of Set 13 | hayato
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 13 | santa cruz de la palma
# Processing Record 49 of Set 13 | bongandanga
# Processing Record 50 of Set 13 | inirida
# Processing Record 1 of Set 14 | abu dhabi
# Processing Record 2 of Set 14 | sinnamary
# Processing Record 3 of Set 14 | santa isabel
# Processing Record 4 of Set 14 | bontang
# Processing Record 5 of Set 14 | leticia
# Processing Record 6 of Set 14 | iturama
# Processing Record 7 of Set 14 | cam ranh
# Processing Record 8 of Set 14 | boende
# Processing Record 9 of Set 14 | aksu
# Processing Record 10 of Set 14 | kasempa
# Processing Record 11 of Set 14 | carazinho
# Processing Record 12 of Set 14 | manicore
# Processing Record 13 of Set 14 | seymchan
# Processing Record 14 of Set 14 | atambua
# Processing Record 15 of Set 14 | fort nelson
# Processing Record 16 of Set 14 | stephenville
# Processing Record 17 of Set 14 | bonavista
# Processing Record 18 of Set 14 | zeulenroda
# Processing Record 19 of Set 14 | aswan
# Processing Record 20 of Set 14 | henderson
# Processing Record 21 of Set 14 | mahibadhoo
# Processing Record 22 of Set 14 | puerto escondido
# Processing Record 23 of Set 14 | pingliang
# Processing Record 24 of Set 14 | mitu
# Processing Record 25 of Set 14 | todos santos
# Processing Record 26 of Set 14 | grao mogol
# Processing Record 27 of Set 14 | dongying
# Processing Record 28 of Set 14 | hun
# Processing Record 29 of Set 14 | nguiu
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 14 | revelstoke
# Processing Record 31 of Set 14 | aras
# Processing Record 32 of Set 14 | nagyhegyes
# Processing Record 33 of Set 14 | pregassona
# Processing Record 34 of Set 14 | cacapava do sul
# Processing Record 35 of Set 14 | azimur
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 14 | coahuayana
# Processing Record 37 of Set 14 | kemerovo
# Processing Record 38 of Set 14 | cotonou
# Processing Record 39 of Set 14 | berlevag
# Processing Record 40 of Set 14 | riviere-au-renard
# Processing Record 41 of Set 14 | kenora
# Processing Record 42 of Set 14 | thunder bay
# Processing Record 43 of Set 14 | kushima
# Processing Record 44 of Set 14 | hofn
# Processing Record 45 of Set 14 | khandyga
# Processing Record 46 of Set 14 | imbituba
# Processing Record 47 of Set 14 | bicaz
# Processing Record 48 of Set 14 | brufut
# Processing Record 49 of Set 14 | balykshi
# Processing Record 50 of Set 14 | walvis bay
# Processing Record 1 of Set 15 | kedrovyy
# Processing Record 2 of Set 15 | san matias
# Processing Record 3 of Set 15 | amuntai
# Processing Record 4 of Set 15 | gorontalo
# Processing Record 5 of Set 15 | merauke
# Processing Record 6 of Set 15 | dinsor
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 15 | pocatello
# Processing Record 8 of Set 15 | spearfish
# Processing Record 9 of Set 15 | nalut
# Processing Record 10 of Set 15 | college
# Processing Record 11 of Set 15 | rio gallegos
# Processing Record 12 of Set 15 | inverness
# Processing Record 13 of Set 15 | klyuchi
# Processing Record 14 of Set 15 | karasjok
# Processing Record 15 of Set 15 | canandaigua
# Processing Record 16 of Set 15 | majene
# Processing Record 17 of Set 15 | banjar
# Processing Record 18 of Set 15 | kalmanka
# Processing Record 19 of Set 15 | vysokaya gora
# Processing Record 20 of Set 15 | buariki
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 15 | chuguyevka
# Processing Record 22 of Set 15 | muroto
# Processing Record 23 of Set 15 | coruripe
# Processing Record 24 of Set 15 | lakes entrance
# Processing Record 25 of Set 15 | povenets
# Processing Record 26 of Set 15 | richards bay
# Processing Record 27 of Set 15 | leshukonskoye
# Processing Record 28 of Set 15 | tura
# Processing Record 29 of Set 15 | lodja
# Processing Record 30 of Set 15 | constantine
# Processing Record 31 of Set 15 | igrim
# Processing Record 32 of Set 15 | deputatskiy
# Processing Record 33 of Set 15 | akora
# Processing Record 34 of Set 15 | sabang
# Processing Record 35 of Set 15 | saquarema
# Processing Record 36 of Set 15 | pasinler
# Processing Record 37 of Set 15 | shingu
# Processing Record 38 of Set 15 | kibara
# Processing Record 39 of Set 15 | konevo
# Processing Record 40 of Set 15 | trogir
# Processing Record 41 of Set 15 | buzmeyin
# Processing Record 42 of Set 15 | ambon
# Processing Record 43 of Set 15 | petrokamenskoye
# Processing Record 44 of Set 15 | kimbe
# Processing Record 45 of Set 15 | dzhusaly
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 15 | huilong
# Processing Record 47 of Set 15 | mgandu
# Processing Record 48 of Set 15 | troitsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Provideniya  64.3833 -173.3000      3.54        84          19        4.79
# 1        Vardo  70.3705   31.1107     23.65        77          84        4.56
# 2    Hay River  60.8156 -115.7999     -4.02        77         100        9.22
# 3   Zyryanovsk  49.7386   84.2719     -9.63        95          95        0.89
# 4  Yellowknife  62.4560 -114.3525    -14.58        78          40        5.75
# 5       Aykino  62.2248   49.9922     13.51        95         100        5.91
# 6        Vaini -21.2000 -175.2000     81.90        76          99       11.95
# 7      Aklavik  68.2191 -135.0107    -17.57        87         100        5.35
# 8    Busselton -33.6500  115.3333     84.24        45           4       12.55
# 9  New Norfolk -42.7826  147.0587     82.65        29           0        1.99
#
#   Country Current Description
# 0      RU          few clouds
# 1      NO       broken clouds
# 2      CA          light snow
# 3      KZ     overcast clouds
# 4      CA    scattered clouds
# 5      RU     overcast clouds
# 6      TO          light rain
# 7      CA     overcast clouds
# 8      AU           clear sky
# 9      AU           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Provideniya      RU  64.3833 -173.3000      3.54        84          19
# 1        Vardo      NO  70.3705   31.1107     23.65        77          84
# 2    Hay River      CA  60.8156 -115.7999     -4.02        77         100
# 3   Zyryanovsk      KZ  49.7386   84.2719     -9.63        95          95
# 4  Yellowknife      CA  62.4560 -114.3525    -14.58        78          40
# 5       Aykino      RU  62.2248   49.9922     13.51        95         100
# 6        Vaini      TO -21.2000 -175.2000     81.90        76          99
# 7      Aklavik      CA  68.2191 -135.0107    -17.57        87         100
# 8    Busselton      AU -33.6500  115.3333     84.24        45           4
# 9  New Norfolk      AU -42.7826  147.0587     82.65        29           0
#
#    Wind Speed Current Description
# 0        4.79          few clouds
# 1        4.56       broken clouds
# 2        9.22          light snow
# 3        0.89     overcast clouds
# 4        5.75    scattered clouds
# 5        5.91     overcast clouds
# 6       11.95          light rain
# 7        5.35     overcast clouds
# 8       12.55           clear sky
# 9        1.99           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15952/1925920037.py in <module>
#       2 output_data_file = "Weather_Database/WeatherPy_Database.csv"
#       3 # Export the City_Data into a CSV.
# ----> 4 city_data_df.to_csv(output_data_file, index_label="City_ID")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
